# %% [markdown]
# # Tasks
#
# 1. Now that the pickles have been made, combine the relevant calculations into a master file and re-check the green text graphs.

# %% [markdown]
# # Preliminaries
# This notebook has the code to make figures 1 & 2 in the manuscript (and related flux, load, and power plots as a function of concentration).

# %%
from simulation import *
from aesthetics import *
from models import *
from data import *
from analysis import *

import glob
import os as os
import re as re
import pandas as pd

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
mpl.rc('text', usetex=True)
cmap = sns.color_palette("Paired", 10)
concentration = 10**-3

# %% [markdown]
# # ADK

# %%
adk_dir = '../../md-data/adenylate-kinase/'
adk_unbound_files = sorted(glob.glob(adk_dir + 'AdKDihedHist_apo-4ake/' + '*'))
names = []

for file in range(len(adk_unbound_files)):
    name = os.path.splitext(os.path.basename(adk_unbound_files[file]))[0]
    name = re.search('^[^_]*', name).group(0)        
    if re.search('omega*', name):
        continue
    if re.search('chi3ASN*', name):
        continue
    if re.search('chi5LYS*', name):
        continue
    names.append(name)

# %%
for name in names:
    this = simulation(data_source = 'adk_md_data')
    this.cSubstrate = concentration
    this.name = name
    this.simulate()
    this.plot_input(save=True, filename='figures/'+name+'-input')
    this.plot_energy(save=True, filename='figures/'+name+'-energy')
    this.plot_flux(save=True, filename='figures/'+name+'-flux')
    del this
# Out:
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         -1.44e-01  cycle second**-1
# Peak intrasurface flux    +1.06e+01  cycle second**-1
# Intersurface flux         +2.25e-05  cycle second**-1
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         -7.51e-03  cycle second**-1
# Peak intrasurface flux    +3.12e+00  cycle second**-1
# Intersurface flux         +1.86e-05  cycle second**-1
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         -3.30e-02  cycle second**-1
# Peak intrasurface flux    +7.07e+00  cycle second**-1
# Intersurface flux         +1.05e-05  cycle second**-1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-8536354777b0> in <module>()
#       5     this.simulate()
#       6     this.plot_input(save=True, filename='figures/'+name+'-input')
# ----> 7     this.plot_energy(save=True, filename='figures/'+name+'-energy')
#       8     this.plot_flux(save=True, filename='figures/'+name+'-flux')
#       9     del this
#
# /media/dslochower/data-beta/projects/nonequilibrium/code/SG-model-v2/simulation.py in plot_energy(self, save, filename)
#     123         aesthetics.paper_plot(fig, scientific=False)
#     124         if save:
# --> 125             plt.savefig(filename + '.png', dpi=300, bbox_inches='tight')
#     126
#     127     def plot_ss(self, save=False, filename=None):
#
# /home/dslochower/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     686 def savefig(*args, **kwargs):
#     687     fig = gcf()
# --> 688     res = fig.savefig(*args, **kwargs)
#     689     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     690     return res
#
# /home/dslochower/anaconda3/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1563             self.set_frameon(frameon)
#    1564
# -> 1565         self.canvas.print_figure(*args, **kwargs)
#    1566
#    1567         if frameon:
#
# /home/dslochower/anaconda3/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2230                 orientation=orientation,
#    2231                 bbox_inches_restore=_bbox_inches_restore,
# -> 2232                 **kwargs)
#    2233         finally:
#    2234             if bbox_inches and restore_bbox:
#
# /home/dslochower/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     535             close = False
#     536         try:
# --> 537             _png.write_png(renderer._renderer, filename_or_obj, self.figure.dpi)
#     538         finally:
#     539             if close:
#
# KeyboardInterrupt:
