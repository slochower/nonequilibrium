# %%
from simulation import *
from aesthetics import *
from models import *
from data import *
import os as os
import re as re
import pandas as pd

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
mpl.rc('text', usetex=True)

# %% [markdown]
# # A model for flux prediction
# - Reflect at 2*pi and compute JSD with reflection, then add the JSD value for each surface.
# - Move by 1 bin and repeat.
# - Note the lowest sum (for any bin shift) of JSDs. Call this J_symmetric.
#
# - Compute the PDF on each surface (done)
# - Compute the JDF between the PMFs. Call this J_bind.
#
# - p_min: lowest probability means there is a high barrier.
#
# Then:
# f = J_symmetric * J_bind * p_min.

# %%
def JSD(x, y): #Jensen-shannon divergence
    x = np.array(x)
    y = np.array(y)
    d1 = x * np.log2(2 * x / (x + y))
    d2 = y * np.log2(2 * y / (x + y))
    d1[np.isnan(d1)] = 0
    d2[np.isnan(d2)] = 0
    d = 0.5 * np.sum(d1 + d2)
    return d

# %%
def permute(x, shift):
    return np.roll(x, shift)

# %%
def reflect(x, point):
    return np.concatenate((x[point:], x[:point]))[::-1]

# %%
df = pd.DataFrame()
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        data = np.genfromtxt(unbound_files[file])[1:]
        J_symmetric = 1.0
        for permutation in range(len(data)):
            J = JSD(data, reflect(data, permutation))
            if J < J_symmetric:
                J_symmetric = J
        df = df.append(pd.DataFrame({'Name': short_name,
                                     'J_symmetric': J_symmetric}, index=[0]), ignore_index=True)

# %%
df.head()
# Out:
#    J_symmetric        Name
# 0     0.133388  chi1ARG119
# 1     0.189839  chi1ARG120
# 2     0.042087  chi1ARG123
# 3     0.043733  chi1ARG130
# 4     0.021699  chi1ARG151

# %%
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        unbound_data = np.genfromtxt(unbound_files[file])[1:]
        bound_data = np.genfromtxt(bound_files[file])[1:]
        J = JSD(unbound_data, bound_data)
        df.loc[file, 'J_bind'] = J

# %%
df.head()
# Out:
#    J_symmetric        Name    J_bind
# 0     0.133388  chi1ARG119  0.011806
# 1     0.189839  chi1ARG120  0.046672
# 2     0.042087  chi1ARG123  0.027365
# 3     0.043733  chi1ARG130  0.005905
# 4     0.021699  chi1ARG151  0.167753

# %%
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        unbound_data = np.genfromtxt(unbound_files[file])[1:]
        bound_data = np.genfromtxt(bound_files[file])[1:]
        p_min = min(np.concatenate((unbound_data, bound_data)))
        df.loc[file, 'p_min'] = p_min

# %%
df.head()
# Out:
#    J_symmetric        Name    J_bind  p_min
# 0     0.133388  chi1ARG119  0.011806    0.0
# 1     0.189839  chi1ARG120  0.046672    0.0
# 2     0.042087  chi1ARG123  0.027365    0.0
# 3     0.043733  chi1ARG130  0.005905    0.0
# 4     0.021699  chi1ARG151  0.167753    0.0

# %%
df['Mike'] = df['J_bind'] * df['J_symmetric'] * df['p_min']

# %%
df.sort_values('Mike', ascending=False)
# Out:
#       J_symmetric        Name    J_bind     p_min          Mike
# 391      0.144513  chi2ILE121  0.030752  0.002373  1.054522e-05
# 1128     0.114767    psiGLY36  0.066656  0.000760  5.815523e-06
# 325      0.017022   chi2ASN99  0.077030  0.000398  5.221205e-07
# 319      0.145435  chi2ASN279  0.045090  0.000063  4.131116e-07
# 618      0.078463   chi3MET44  0.023699  0.000105  1.952350e-07
# 615      0.065905  chi3MET106  0.076319  0.000036  1.820795e-07
# 385      0.035407  chi2HIS144  0.020248  0.000145  1.038094e-07
# 320      0.013098  chi2ASN312  0.051165  0.000109  7.277921e-08
# 323      0.061373   chi2ASN76  0.003513  0.000315  6.791110e-08
# 1123     0.094341   psiGLY268  0.017366  0.000036  5.930758e-08
# 318      0.019629  chi2ASN275  0.037542  0.000072  5.335275e-08
# 990      0.008289   phiVAL205  0.015583  0.000252  3.254744e-08
# 322      0.016783   chi2ASN53  0.008336  0.000181  2.532281e-08
# 315      0.034528  chi2ASN257  0.006892  0.000105  2.498451e-08
# 551      0.146719  chi3GLN260  0.006402  0.000021  1.972267e-08
# 317      0.008325  chi2ASN272  0.108671  0.000021  1.899703e-08
# 606      0.014905   chi3LYS64  0.020838  0.000021  6.521937e-09
# 389      0.008417   chi2HIS54  0.016017  0.000021  2.830908e-09
# 890      0.025696   phiMET104  0.008186  0.000000  0.000000e+00
# 898      0.004654    phiPHE12  0.004658  0.000000  0.000000e+00
# 897      0.009610   phiPHE124  0.001069  0.000000  0.000000e+00
# 896      0.005146   phiPHE115  0.055410  0.000000  0.000000e+00
# 922      0.001689   phiPRO155  0.024376  0.000000  0.000000e+00
# 895      0.011297    phiMET57  0.006336  0.000000  0.000000e+00
# 921      0.017928   phiPRO127  0.019898  0.000000  0.000000e+00
# 918      0.002040    phiPHE88  0.005296  0.000000  0.000000e+00
# 891      0.007318   phiMET106  0.002573  0.000000  0.000000e+00
# 894      0.006913    phiMET44  0.007818  0.000000  0.000000e+00
# 893      0.021721   phiMET217  0.038863  0.000000  0.000000e+00
# 900      0.015107   phiPHE140  0.011973  0.000000  0.000000e+00
# ...           ...         ...       ...       ...           ...
# 434      0.076401  chi2LEU270  0.004147  0.000000  0.000000e+00
# 433      0.030414   chi2LEU26  0.106171  0.000000  0.000000e+00
# 432      0.062201  chi2LEU263  0.009812  0.000000  0.000000e+00
# 431      0.027671  chi2LEU259  0.024297  0.000000  0.000000e+00
# 430      0.040616  chi2LEU258  0.001363  0.000000  0.000000e+00
# 429      0.018238  chi2LEU255  0.019376  0.000000  0.000000e+00
# 428      0.044583  chi2LEU254  0.002317  0.000000  0.000000e+00
# 445      0.017106  chi2LYS154  0.002954  0.000000  0.000000e+00
# 446      0.017924   chi2LYS15  0.086511  0.000000  0.000000e+00
# 447      0.020334  chi2LYS175  0.001863  0.000000  0.000000e+00
# 457      0.067665  chi2LYS281  0.024522  0.000000  0.000000e+00
# 464      0.059865   chi2LYS33  0.005161  0.000000  0.000000e+00
# 463      0.001264  chi2LYS331  0.010717  0.000000  0.000000e+00
# 462      0.056047  chi2LYS328  0.019401  0.000000  0.000000e+00
# 461      0.019852  chi2LYS305  0.005891  0.000000  0.000000e+00
# 460      0.026699  chi2LYS303  0.005578  0.000000  0.000000e+00
# 459      0.008599    chi2LYS2  0.013240  0.000000  0.000000e+00
# 458      0.044498  chi2LYS295  0.007715  0.000000  0.000000e+00
# 456      0.007423  chi2LYS278  0.006616  0.000000  0.000000e+00
# 448      0.001585  chi2LYS178  0.032192  0.000000  0.000000e+00
# 455      0.013553  chi2LYS271  0.020818  0.000000  0.000000e+00
# 454      0.096957  chi2LYS265  0.002128  0.000000  0.000000e+00
# 453      0.020563  chi2LYS252  0.002380  0.000000  0.000000e+00
# 452      0.044390  chi2LYS240  0.016448  0.000000  0.000000e+00
# 451      0.040538  chi2LYS235  0.132726  0.000000  0.000000e+00
# 450      0.099309  chi2LYS203  0.003780  0.000000  0.000000e+00
# 449      0.201059  chi2LYS199  0.019923  0.000000  0.000000e+00
# 1339     0.067563    psiVAL90  0.044280  0.000000  0.000000e+00
# 49       0.016172  chi1CYS329       NaN       NaN           NaN
# 1340          NaN         NaN  0.053205  0.000000           NaN
#
# [1341 rows x 5 columns]
