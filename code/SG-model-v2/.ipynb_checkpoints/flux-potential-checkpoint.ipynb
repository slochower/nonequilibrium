# %%
from simulation import *
from aesthetics import *
from models import *
from data import *
import os as os
import re as re
import pandas as pd

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
mpl.rc('text', usetex=True)

# %% [markdown]
# # A model for flux prediction
# - Reflect at 2*pi and compute JSD with reflection, then add the JSD value for each surface.
# - Move by 1 bin and repeat.
# - Note the lowest sum (for any bin shift) of JSDs. Call this J_symmetric.
#
# - Compute the PDF on each surface (done)
# - Compute the JDF between the PMFs. Call this J_bind.
#
# - p_min: lowest probability means there is a high barrier.
#
# Then:
# f = J_symmetric * J_bind * p_min.

# %%
def JSD(x, y): #Jensen-shannon divergence
    x = np.array(x)
    y = np.array(y)
    d1 = x * np.log2(2 * x / (x + y))
    d2 = y * np.log2(2 * y / (x + y))
    d1[np.isnan(d1)] = 0
    d2[np.isnan(d2)] = 0
    d = 0.5 * np.sum(d1 + d2)
    return d

# %%
def permute(x, shift):
    return np.roll(x, shift)

# %%
def reflect(x, point):
    return np.concatenate((x[point:], x[:point]))[::-1]

# %%
df = pd.DataFrame()
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        data = np.genfromtxt(unbound_files[file])[1:]
        J_symmetric = 1.0
        for permutation in range(len(data)):
            J = JSD(data, reflect(data, permutation))
            if J < J_symmetric:
                J_symmetric = J
        df = df.append(pd.DataFrame({'Name': short_name,
                                     'J_symmetric': J_symmetric}, index=[0]), ignore_index=True)

# %%
tmp = pd.DataFrame()
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        unbound_data = np.genfromtxt(unbound_files[file])[1:]
        bound_data = np.genfromtxt(bound_files[file])[1:]
        J = JSD(unbound_data, bound_data)
        tmp = tmp.append(pd.DataFrame({'Name': short_name,
                                     'J_bind': J}, index=[0]), ignore_index=True)

# %%
tmp.head()
# Out:
#      J_bind        Name
# 0  0.011806  chi1ARG119
# 1  0.046672  chi1ARG120
# 2  0.027365  chi1ARG123
# 3  0.005905  chi1ARG130
# 4  0.167753  chi1ARG151

# %%
df =df.merge(tmp, on='Name')

# %%
tmp = pd.DataFrame()
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        unbound_data = np.genfromtxt(unbound_files[file])[1:]
        bound_data = np.genfromtxt(bound_files[file])[1:]
        p_min = min(np.concatenate((unbound_data, bound_data)))
        tmp = tmp.append(pd.DataFrame({'Name': short_name,
                                     'p_min': p_min}, index=[0]), ignore_index=True)

# %%
df = df.merge(tmp, on='Name')

# %%
df
# Out:
#       J_symmetric        Name    J_bind  p_min
# 0        0.133388  chi1ARG119  0.011806    0.0
# 1        0.189839  chi1ARG120  0.046672    0.0
# 2        0.042087  chi1ARG123  0.027365    0.0
# 3        0.043733  chi1ARG130  0.005905    0.0
# 4        0.021699  chi1ARG151  0.167753    0.0
# 5        0.032776  chi1ARG176  0.022304    0.0
# 6        0.051289  chi1ARG180  0.043847    0.0
# 7        0.100320  chi1ARG242  0.012198    0.0
# 8        0.102363  chi1ARG256  0.018063    0.0
# 9        0.089394  chi1ARG266  0.088928    0.0
# 10       0.062924  chi1ARG294  0.021259    0.0
# 11       0.111912   chi1ARG31  0.113771    0.0
# 12       0.050744  chi1ARG322  0.199412    0.0
# 13       0.110720   chi1ARG42  0.066454    0.0
# 14       0.199291   chi1ARG79  0.017980    0.0
# 15       0.011359  chi1ASN101  0.017088    0.0
# 16       0.004660  chi1ASN157  0.006323    0.0
# 17       0.145767  chi1ASN202  0.059861    0.0
# 18       0.155221   chi1ASN22  0.011047    0.0
# 19       0.192648  chi1ASN257  0.222826    0.0
# 20       0.044059  chi1ASN269  0.013357    0.0
# 21       0.055905  chi1ASN272  0.079329    0.0
# 22       0.027249  chi1ASN275  0.044831    0.0
# 23       0.217985  chi1ASN279  0.058685    0.0
# 24       0.104938  chi1ASN312  0.141836    0.0
# 25       0.078142  chi1ASN326  0.020319    0.0
# 26       0.018330   chi1ASN53  0.007264    0.0
# 27       0.113263   chi1ASN76  0.025815    0.0
# 28       0.180244   chi1ASN85  0.057244    0.0
# 29       0.123783   chi1ASN99  0.031067    0.0
# ...           ...         ...       ...    ...
# 1310     0.041217   psiTYR150  0.138618    0.0
# 1311     0.012380   psiTYR165  0.015457    0.0
# 1312     0.007102   psiTYR190  0.634054    0.0
# 1313     0.025050   psiTYR201  0.012815    0.0
# 1314     0.018335   psiTYR215  0.047988    0.0
# 1315     0.023853   psiTYR221  0.006609    0.0
# 1316     0.017763   psiTYR233  0.007497    0.0
# 1317     0.023899   psiTYR292  0.035352    0.0
# 1318     0.004632   psiTYR316  0.074775    0.0
# 1319     0.001709    psiTYR55  0.025456    0.0
# 1320     0.015216   psiVAL105  0.093948    0.0
# 1321     0.166713   psiVAL109  0.655896    0.0
# 1322     0.003517   psiVAL137  0.137464    0.0
# 1323     0.016978   psiVAL168  0.040872    0.0
# 1324     0.012672   psiVAL177  0.020738    0.0
# 1325     0.079892     psiVAL1  0.235873    0.0
# 1326     0.005954   psiVAL205  0.154976    0.0
# 1327     0.025507   psiVAL212  0.010254    0.0
# 1328     0.014184   psiVAL237  0.009253    0.0
# 1329     0.003794   psiVAL241  0.011826    0.0
# 1330     0.019588   psiVAL261  0.005940    0.0
# 1331     0.003541   psiVAL274  0.635077    0.0
# 1332     0.011470   psiVAL296  0.008183    0.0
# 1333     0.032820   psiVAL323  0.318735    0.0
# 1334     0.005937    psiVAL43  0.008795    0.0
# 1335     0.015793    psiVAL46  0.012075    0.0
# 1336     0.020847    psiVAL65  0.017371    0.0
# 1337     0.007082    psiVAL66  0.015813    0.0
# 1338     0.012702    psiVAL84  0.044280    0.0
# 1339     0.067563    psiVAL90  0.053205    0.0
#
# [1340 rows x 4 columns]

# %%
df['Mike'] = df['J_bind'] * df['J_symmetric'] * df['p_min']

# %%
df.sort_values('Mike', ascending=False)
# Out:
#       J_symmetric        Name    J_bind     p_min          Mike
# 390      0.049324   chi2HIS73  0.030752  0.002373  3.599246e-06
# 1127     0.070685   psiGLY330  0.066656  0.000760  3.581799e-06
# 460      0.026699  chi2LYS303  0.005891  0.000000  0.000000e+00
# 459      0.008599    chi2LYS2  0.005578  0.000000  0.000000e+00
# 458      0.044498  chi2LYS295  0.013240  0.000000  0.000000e+00
# 456      0.007423  chi2LYS278  0.024522  0.000000  0.000000e+00
# 448      0.001585  chi2LYS178  0.019923  0.000000  0.000000e+00
# 455      0.013553  chi2LYS271  0.006616  0.000000  0.000000e+00
# 454      0.096957  chi2LYS265  0.020818  0.000000  0.000000e+00
# 453      0.020563  chi2LYS252  0.002128  0.000000  0.000000e+00
# 452      0.044390  chi2LYS240  0.002380  0.000000  0.000000e+00
# 451      0.040538  chi2LYS235  0.016448  0.000000  0.000000e+00
# 450      0.099309  chi2LYS203  0.132726  0.000000  0.000000e+00
# 449      0.201059  chi2LYS199  0.003780  0.000000  0.000000e+00
# 1339     0.067563    psiVAL90  0.053205  0.000000  0.000000e+00
#
# [1340 rows x 5 columns]

# %%
import pickle

# %%
with open('Flux-results.pickle', 'rb') as pickle_file:
    flux = pickle.load(pickle_file)

# %%
df['File'] = df['Name']
correlation = pd.DataFrame()
correlation = df.merge(flux, on='File')

# %%
correlation
# Out:
#       J_symmetric        Name    J_bind  p_min  Mike        File  \
# 0        0.133388  chi1ARG119  0.011806    0.0   0.0  chi1ARG119
# 1        0.189839  chi1ARG120  0.046672    0.0   0.0  chi1ARG120
# 2        0.042087  chi1ARG123  0.027365    0.0   0.0  chi1ARG123
# 3        0.043733  chi1ARG130  0.005905    0.0   0.0  chi1ARG130
# 4        0.021699  chi1ARG151  0.167753    0.0   0.0  chi1ARG151
# 5        0.032776  chi1ARG176  0.022304    0.0   0.0  chi1ARG176
# 6        0.051289  chi1ARG180  0.043847    0.0   0.0  chi1ARG180
# 7        0.100320  chi1ARG242  0.012198    0.0   0.0  chi1ARG242
# 8        0.102363  chi1ARG256  0.018063    0.0   0.0  chi1ARG256
# 9        0.089394  chi1ARG266  0.088928    0.0   0.0  chi1ARG266
# 10       0.062924  chi1ARG294  0.021259    0.0   0.0  chi1ARG294
# 11       0.111912   chi1ARG31  0.113771    0.0   0.0   chi1ARG31
# 12       0.050744  chi1ARG322  0.199412    0.0   0.0  chi1ARG322
# 13       0.110720   chi1ARG42  0.066454    0.0   0.0   chi1ARG42
# 14       0.199291   chi1ARG79  0.017980    0.0   0.0   chi1ARG79
# 15       0.011359  chi1ASN101  0.017088    0.0   0.0  chi1ASN101
# 16       0.004660  chi1ASN157  0.006323    0.0   0.0  chi1ASN157
# 17       0.145767  chi1ASN202  0.059861    0.0   0.0  chi1ASN202
# 18       0.155221   chi1ASN22  0.011047    0.0   0.0   chi1ASN22
# 19       0.192648  chi1ASN257  0.222826    0.0   0.0  chi1ASN257
# 20       0.044059  chi1ASN269  0.013357    0.0   0.0  chi1ASN269
# 21       0.055905  chi1ASN272  0.079329    0.0   0.0  chi1ASN272
# 22       0.027249  chi1ASN275  0.044831    0.0   0.0  chi1ASN275
# 23       0.217985  chi1ASN279  0.058685    0.0   0.0  chi1ASN279
# 24       0.104938  chi1ASN312  0.141836    0.0   0.0  chi1ASN312
# 25       0.078142  chi1ASN326  0.020319    0.0   0.0  chi1ASN326
# 1313                    0.009905    -0.011253
# 1314                    0.005907    -0.422487
# 1315                    0.011819    -0.685132
# 1316                    0.007198    -0.638294
# 1317                    0.010655    -0.669438
# 1318                    0.029461   -11.107279
# 1319                    0.004143    -0.643312
# 1320                    0.009458     0.875538
# 1321                    0.016498  -452.044354
# 1322                    0.137834     1.021757
# 1323                    0.006007    -0.180250
# 1324                    0.016609     0.752015
# 1325                    0.005251   410.694137
# 1326                    1.249069     0.302254
# 1327                    0.047710    -0.499871
# 1328                    0.009879    -0.428697
# 1329                    0.003072    -3.912828
# 1330                    0.008680    -1.289649
# 1331                    0.011494   -19.762466
# 1332                    0.006415     1.175036
# 1333                    0.127546    22.721539
# 1334                    0.007312     1.282124
# 1335                    0.006859    -0.116134
# 1336                    0.004388    -5.826428
# 1337                    0.004408     1.836499
# 1338                    0.004468     0.885253
# 1339                    0.005054    -0.079126
#
# [1340 rows x 11 columns]

# %%
plt.plot(correlation['Mike'], correlation['Flux with catalysis'])

# %%
correlation[correlation['p_min'] > 0]
# Out:
#       J_symmetric        Name    J_bind     p_min          Mike        File  \
# 314      0.089880   chi2ASN22  0.006892  0.000105  6.503706e-08   chi2ASN22
# 316      0.039028  chi2ASN269  0.108671  0.000021  8.906062e-08  chi2ASN269
# 317      0.008325  chi2ASN272  0.037542  0.000072  2.262800e-08  chi2ASN272
# 318      0.019629  chi2ASN275  0.045090  0.000063  5.575579e-08  chi2ASN275
# 319      0.145435  chi2ASN279  0.051165  0.000109  8.081159e-07  chi2ASN279
# 321      0.023854  chi2ASN326  0.008336  0.000181  3.599156e-08  chi2ASN326
# 322      0.016783   chi2ASN53  0.003513  0.000315  1.857073e-08   chi2ASN53
# 324      0.097132   chi2ASN85  0.077030  0.000398  2.979414e-06   chi2ASN85
# 384      0.128233  chi2HIS128  0.020248  0.000145  3.759665e-07  chi2HIS128
# 388      0.024056   chi2HIS48  0.016017  0.000021  8.090719e-09   chi2HIS48
# 390      0.049324   chi2HIS73  0.030752  0.002373  3.599246e-06   chi2HIS73
# 550      0.009458   chi3GLN25  0.006402  0.000021  1.271348e-09   chi3GLN25
# 605      0.067521   chi3LYS62  0.020838  0.000021  2.954474e-08   chi3LYS62
# 614      0.154191  chi3MET104  0.076319  0.000036  4.259936e-07  chi3MET104
# 617      0.020569  chi3MET217  0.023699  0.000105  5.118025e-08  chi3MET217
# 989      0.000864     phiVAL1  0.015583  0.000252  3.390646e-09     phiVAL1
# 1122     0.030602   psiGLY239  0.017366  0.000036  1.923783e-08   psiGLY239
# 1127     0.070685   psiGLY330  0.066656  0.000760  3.581799e-06   psiGLY330
#
#       Flux with catalysis  Flux with catalysis SEM  Flux without catalysis  \
# 314             -0.021266                 0.001649                0.000560
# 316              0.741779                 0.002441                0.047384
# 317              0.205536                 0.002395                0.001263
# 318              0.327886                 0.002734                0.011890
# 319             -0.002048                 0.001356               -0.011157
# 321              0.114071                 0.002283               -0.006608
# 322              0.010918                 0.001143                0.009840
# 324              0.614172                 0.003477                0.002654
# 384             -0.104652                 0.003188                0.010422
# 388             -0.031817                 0.001821               -0.018895
# 390             -0.052398                 0.001590                0.002768
# 550             -0.030734                 0.004050                0.016839
# 605             -0.030076                 0.003017                0.008289
# 614              2.742404                 0.006792               -0.006824
# 617              0.037333                 0.002163                0.006097
# 989             -0.005844                 0.001036               -0.003966
# 1122             0.680791                 0.002205               -0.008273
# 1127            -1.472932                 0.004504               -0.003839
#
#       Flux without catalysis SEM       Ratio
# 314                     0.003701  -37.987043
# 316                     0.008384   15.654646
# 317                     0.001357  162.714779
# 318                     0.002325   27.576545
# 319                     0.001448    0.183540
# 321                     0.003371  -17.262420
# 322                     0.002198    1.109488
# 324                     0.002712  231.428144
# 384                     0.002363  -10.041759
# 388                     0.003995    1.683892
# 390                     0.001302  -18.927371
# 550                     0.007494   -1.825118
# 605                     0.005946   -3.628309
# 614                     0.002074 -401.866653
# 617                     0.003440    6.122982
# 989                     0.001577    1.473303
# 1122                    0.004370  -82.288501
# 1127                    0.002905  383.673589

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(correlation[correlation['p_min'] > 0]['Mike'], correlation[correlation['p_min'] > 0]['Flux with catalysis'])
ax.set_xlabel('Mike\'s metric')
ax.set_ylabel('Flux')
ax.set_title('Files with nonzero p\_min')
ax.set_xlim([0.000000001, 0.000001])
fetching_plot(fig)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(correlation['J_symmetric'] * correlation['J_bind'], correlation['Flux with catalysis'])
ax.set_xlabel(r'$J_\text{symmetric} \cdot J_\text{bind}$')
ax.set_ylabel('Flux')
fetching_plot(fig)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(correlation['J_symmetric'], correlation['Flux with catalysis'])
ax.set_xlabel(r'$J_\text{symmetric}$')
ax.set_ylabel('Flux')
fetching_plot(fig)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(correlation['J_bind'], correlation['Flux with catalysis'])
ax.set_xlabel(r'$J_\text{bind}$')
ax.set_ylabel('Flux')
ax.set_xlim
fetching_plot(fig)

# %%
frocorrelation.sort_values('Flux with catalysis', ascending=False)[0:20]
# Out:
#       J_symmetric        Name    J_bind  p_min  Mike        File  \
# 1281     0.029831   psiSER311  0.429173    0.0   0.0   psiSER311
# 194      0.064510  chi1PHE173  0.302436    0.0   0.0  chi1PHE173
# 32       0.107566  chi1ASP152  0.215674    0.0   0.0  chi1ASP152
# 4        0.021699  chi1ARG151  0.167753    0.0   0.0  chi1ARG151
# 83       0.045693    chi1GLU3  0.074232    0.0   0.0    chi1GLU3
# 392      0.027576  chi2ILE136  0.051351    0.0   0.0  chi2ILE136
# 357      0.082659   chi2GLN70  0.219620    0.0   0.0   chi2GLN70
# 43       0.026511  chi1ASP309  0.262769    0.0   0.0  chi1ASP309
# 207      0.035980   chi1PHE40  0.106948    0.0   0.0   chi1PHE40
# 100      0.143882  chi1ILE166  0.148744    0.0   0.0  chi1ILE166
# 152      0.081439  chi1LYS175  0.392886    0.0   0.0  chi1LYS175
# 244      0.042344  chi1THR181  0.301519    0.0   0.0  chi1THR181
# 167      0.099432  chi1LYS328  0.051710    0.0   0.0  chi1LYS328
# 266      0.227380  chi1TYR150  0.209769    0.0   0.0  chi1TYR150
# 71       0.138002  chi1GLU189  0.400888    0.0   0.0  chi1GLU189
# 112      0.030898  chi1ILE325  0.040112    0.0   0.0  chi1ILE325
# 312      0.084145  chi2ASN157  0.944087    0.0   0.0  chi2ASN157
# 353      0.108325  chi2GLN260  0.172663    0.0   0.0  chi2GLN260
# 508      0.023198   chi2TRP16  0.119806    0.0   0.0   chi2TRP16
# 228      0.085247  chi1SER116  0.031238    0.0   0.0  chi1SER116
#
#       Flux with catalysis  Flux with catalysis SEM  Flux without catalysis  \
# 1281            33.652281                 0.004932               -0.051298
# 194             31.200045                 0.014472               -0.078738
# 32              25.618597                 0.002859               -0.020989
# 4               24.574252                 0.045719                0.709663
# 83              22.402664                 0.009573                0.025930
# 392             22.000327                 0.113141               -1.183333
# 357             21.601027                 0.002754                0.016187
# 43              20.386404                 0.006846               -0.062922
# 207             20.363098                 0.049409                0.107012
# 100             18.442161                 0.053690                0.087870
# 152             17.617009                 0.004021               -0.019821
# 244             16.163381                 0.004021                0.032015
# 167             15.626761                 0.072204               -0.495939
# 266             15.259539                 0.008620                0.063878
# 71              14.768451                 0.003482                0.040919
# 112             14.254896                 0.037379               -0.011568
# 312             12.099231                 0.007361               -0.002351
# 353             10.769071                 0.007362                0.001195
# 508             10.244248                 0.074271                0.084063
# 228              9.135702                 0.056855                0.047336
#
#       Flux without catalysis SEM        Ratio
# 1281                    0.008780  -656.017735
# 194                     0.012200  -396.249657
# 32                      0.007605 -1220.552886
# 4                       0.070110    34.628067
# 83                      0.004183   863.983257
# 392                     0.132258   -18.591826
# 357                     0.007527  1334.480608
# 43                      0.002633  -323.996746
# 207                     0.099053   190.287206
# 100                     0.021395   209.879491
# 152                     0.009382  -888.806079
# 244                     0.009662   504.862409
# 167                     0.095115   -31.509449
# 266                     0.028711   238.884869
# 71                      0.004908   360.917041
# 112                     0.051344 -1232.258926
# 312                     0.002750 -5146.262621
# 353                     0.006497  9010.513937
# 508                     0.119932   121.864191
# 228                     0.033539   192.996239

# %%
x = correlation.sort_values('Flux with catalysis', ascending=False)[0:50]['J_bind'] * correlation.sort_values('Flux with catalysis', ascending=False)[0:50]['J_symmetric']
y = correlation.sort_values('Flux with catalysis', ascending=False)[0:50]['Flux with catalysis']

slope, intercept, r, pval, stderr = sc.stats.linregress(x, y)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x, y)
ax.plot([i for i in x], [slope * i + intercept for i in x], label=r'R$^{{2}}$ = {0:0.4f}'.format(r**2), c='k')
ax.set_xlabel(r'$J_\text{symmetric} \cdot J_\text{bind}$')
ax.set_ylabel('Flux')
ax.set_title('Top 50 files with flux')
ax.legend()
fetching_plot(fig)

# %% [markdown]
# # Instead of using `p_min` from the data, used the smoothed `p_min` after processing. Also, plot abs(flux) instead of flux.

# %%
from scipy.ndimage.filters import gaussian_filter
def smooth(x):
    histogram_smooth = gaussian_filter(x, 1)
    histogram_copy = np.copy(x)
    for i in range(len(x)):
        if histogram_smooth[i] != 0:
            histogram_copy[i] = histogram_smooth[i]
        else:
            histogram_copy[i] = min(histogram_smooth[np.nonzero(histogram_smooth)])
    histogram_smooth = histogram_copy
    assert (not np.any(histogram_smooth == 0))
    histogram_smooth /= np.sum(histogram_smooth)
    return histogram_smooth

# %%
df = pd.DataFrame()
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        data = np.genfromtxt(unbound_files[file])[1:]
        data = smooth(data)
        J_symmetric = 1.0
        for permutation in range(len(data)):
            J = JSD(data, reflect(data, permutation))
            if J < J_symmetric:
                J_symmetric = J
        df = df.append(pd.DataFrame({'File': short_name,
                                     'J_symmetric': J_symmetric}, index=[0]), ignore_index=True)
        
tmp = pd.DataFrame()
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        unbound_data = np.genfromtxt(unbound_files[file])[1:]
        unbound_data = smooth(unbound_data)
        bound_data = np.genfromtxt(bound_files[file])[1:]
        bound_data = smooth(bound_data)
        J = JSD(unbound_data, bound_data)
        tmp = tmp.append(pd.DataFrame({'File': short_name,
                                     'J_bind': J}, index=[0]), ignore_index=True)
        
df = df.merge(tmp, on='File')

tmp = pd.DataFrame()
for file in range(len(unbound_files)):
    long_name = os.path.splitext(os.path.basename(unbound_files[file]))[0]
    short_name = re.search('^[^_]*', long_name).group(0)
    if short_name == 'chi1CYM185':
        pass
    else:
        unbound_data = np.genfromtxt(unbound_files[file])[1:]
        unbound_data = smooth(unbound_data)
        bound_data = np.genfromtxt(bound_files[file])[1:]
        bound_data = smooth(bound_data)
        p_min = min(np.concatenate((unbound_data, bound_data)))
        tmp = tmp.append(pd.DataFrame({'File': short_name,
                                     'p_min': p_min}, index=[0]), ignore_index=True)
df = df.merge(tmp, on='File')
df['Mike'] = df['J_bind'] * df['J_symmetric'] * df['p_min']

# %%
df.head()
# Out:
#          File  J_symmetric    J_bind         p_min          Mike
# 0  chi1ARG119     0.116832  0.008482  4.844723e-09  4.801225e-12
# 1  chi1ARG120     0.187298  0.043167  2.810269e-09  2.272106e-11
# 2  chi1ARG123     0.034315  0.026428  8.430807e-09  7.645712e-12
# 3  chi1ARG130     0.041526  0.004374  2.810269e-09  5.104912e-13
# 4  chi1ARG151     0.016208  0.149895  2.810269e-09  6.827568e-12

# %%
df.sort_values('Mike', ascending=False)
# Out:
#             File  J_symmetric    J_bind         p_min          Mike
# 1127   psiGLY330     0.061943  0.062485  9.407035e-04  3.641028e-06
# 324    chi2ASN85     0.090474  0.074804  5.004911e-04  3.387230e-06
# 390    chi2HIS73     0.045304  0.026712  2.760765e-03  3.340990e-06
# 319   chi2ASN279     0.137939  0.046058  1.982689e-04  1.259626e-06
# 614   chi3MET104     0.142791  0.074892  8.236692e-05  8.808305e-07
# 384   chi2HIS128     0.124145  0.017789  2.296864e-04  5.072474e-07
# 1210   psiLYS305     0.075261  0.539513  1.105421e-05  4.488468e-07
# 383   chi2HIS117     0.070430  0.116278  3.363426e-05  2.754486e-07
# 538   chi3ARG294     0.053816  0.096377  5.214123e-05  2.704371e-07
# 651   chi4LYS303     0.000620  0.002233  2.810269e-09  3.894323e-15
# 1111    psiGLU93     0.007294  0.000134  2.810269e-09  2.737235e-15
# 827    phiLEU138     0.000544  0.000969  4.844722e-09  2.556661e-15
# 506    chi2PHE94     0.005017  0.000137  2.810269e-09  1.929517e-15
# 1177   psiLEU254     0.003784  0.000172  2.810269e-09  1.823833e-15
# 1230    psiMET44     0.000069  0.007122  2.810269e-09  1.379912e-15
# 1308   psiTYR132     0.000203  0.002257  2.810269e-09  1.284562e-15
# 517   chi2TYR142     0.001731  0.000234  2.810269e-09  1.139490e-15
# 1097   psiGLU216     0.000528  0.000321  2.810269e-09  4.769000e-16
#
# [1340 rows x 5 columns]

# %%
# df['File'] = df['Name']
correlation = pd.DataFrame()
correlation = df.merge(flux, on='File')

# %%
correlation.head()
# Out:
#          File  J_symmetric    J_bind         p_min          Mike  \
# 0  chi1ARG119     0.116832  0.008482  4.844723e-09  4.801225e-12
# 1  chi1ARG120     0.187298  0.043167  2.810269e-09  2.272106e-11
# 2  chi1ARG123     0.034315  0.026428  8.430807e-09  7.645712e-12
# 3  chi1ARG130     0.041526  0.004374  2.810269e-09  5.104912e-13
# 4  chi1ARG151     0.016208  0.149895  2.810269e-09  6.827568e-12
#
#    Flux with catalysis  Flux with catalysis SEM  Flux without catalysis  \
# 0            -0.085266                 0.006718               -0.058314
# 1             0.065552                 0.011386               -0.028742
# 2            -0.232762                 0.006610               -0.102740
# 3            -0.132464                 0.007214               -0.007966
# 4            24.574252                 0.045719                0.709663
#
#    Flux without catalysis SEM      Ratio
# 0                    0.007144   1.462175
# 1                    0.006518  -2.280685
# 2                    0.015365   2.265536
# 3                    0.004643  16.628032
# 4                    0.070110  34.628067

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(correlation['Mike'], abs(correlation['Flux with catalysis']))
ax.set_xlabel('Flux potential')
ax.set_ylabel('abs(Flux)')
ax.set_title('Metrics computed with smoothed PDFs')
ax.set_xlim([0.000000001, 0.000001])
# ax.set_xscale('log')
fetching_plot(fig)

# %%
bars = []
count = []
mean = []
bins = np.linspace(min(correlation['Mike']), max(correlation['Mike']), 10)
for i in range(len(bins)-1):
#     print('Between {} and {}'.format(bins[i], bins[i+1]))
#     print(len(correlation[(correlation['Mike'] > bins[i]) & 
#                              (correlation['Mike'] < bins[i+1])]))
    bars.append(bins[i])
#     count.append(len(correlation[(correlation['Mike'] > bins[i]) & 
#                               (correlation['Mike'] < bins[i+1])]))
    mean.append(np.mean(abs(correlation[(correlation['Mike'] > bins[i]) & 
                             (correlation['Mike'] < bins[i+1])]['Flux with catalysis'])))

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(bars, mean, width=bars[1] - bars[0])
ax.set_xlabel('Flux potential')
ax.set_ylabel('Mean abs(Flux)')
ax.set_title('Metrics computed with smoothed PDFs')
ax.set_xlim([bins[0], bins[-1]])
# ax.set_xscale('log')
fetching_plot(fig)
ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax.set_xlim([bins[0], bins[-1]])

fetching_plot(fig)

# %%
bars[1] - bars[0]
# Out:
# 1.916330393313925e-07
