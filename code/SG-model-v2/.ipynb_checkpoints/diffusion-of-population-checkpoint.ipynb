# %%
from simulation import *
from aesthetics import *
from models import *
from data import *
import pandas as pd
import scipy as sc
import os as os
import re as re

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
mpl.rc('text', usetex=True)

# %%
name = 'psiSER311'
this = simulation()
this.unbound_population = np.array([1] * 20)
this.bound_population = np.array([1] * 20)
this.iterations = 20
this.simulate(debug=True, pka_md_data=False)
# Out:
# Running iterative method with 20 iterations
# MSD = 1295.9978134697571
# MSD = 1356.0138706635112
# MSD = 1416.0236402168698
# MSD = 1476.0277882266712
# MSD = 1536.0262390290416
# MSD = 1596.0182970333751
# MSD = 1656.002720069548
# MSD = 1715.9777632186115
# MSD = 1775.941205468855
# MSD = 1835.8903671602554
# MSD = 1895.822123278602
# MSD = 1955.7329157340146
# MSD = 2015.6187664793404
# MSD = 2075.475292477174
# MSD = 2135.297722968062
# MSD = 2195.0809191326744
# MSD = 2254.8193960142717
# MSD = 2314.507346431995
# MSD = 2374.1386665414993
# MSD = 2433.7069826671395

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.plot(this.msd)
ax.set_xlabel(r'Iteration [$\mathrm{{d}}t$ = {}]'.format(this.dt))
ax.set_ylabel(r'$\sum_i p_i(x_i - \mu)^2$ [degrees$^2$]')
pretty_plot(fig)

# %%
slope, intercept, r_value, p_value, std_err = sc.stats.linregress(range(len(this.msd)),this.msd)
print('{0:.4g}'.format( (slope/2) * 1/(this.dt)))
# This should match `D` in the code, which is 3e15 :-)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-7-9fcb655c7709> in <module>()
# ----> 1 slope, intercept, r_value, p_value, std_err = sc.stats.linregress(range(len(this.msd)),this.msd)
#       2 print('{0:.4g}'.format( (slope/2) * 1/(this.dt)))
#       3 # This should match `D` in the code, which is 3e15 :-)
#
# AttributeError: 'simulation' object has no attribute 'msd'

# %%
name = 'Test'
this = simulation()
this.unbound_population = np.array([variable_saw(10, i, 60)+10 for i in range(60)])
this.bound_population = np.array([(variable_saw(10, i, 30)+10) for i in range(60)])
this.bins = 60
this.iterations = 0
this.simulate(debug=True, pka_md_data=False, plot=True)
# Out:
# Eigenvector method: C_intrasurface = 8.33e+13, C_intersurface = 240000.0, catalytic rate = 140, cATP = 0.002, dt = 1e-15

# %%
name = 'Test'
this = simulation()
this.unbound = np.array([variable_saw(1, i, 60) for i in range(60)])
this.bound = np.array([(variable_saw(1, i, 30)) for i in range(60)])
this.bins = 60
this.iterations = 0
this.simulate(debug=True, pka_md_data=False, user_energies=True, plot=True)
# Out:
# Eigenvector method: C_intrasurface = 8.33e+13, C_intersurface = 240000.0, catalytic rate = 140, cATP = 0.002, dt = 1e-15
