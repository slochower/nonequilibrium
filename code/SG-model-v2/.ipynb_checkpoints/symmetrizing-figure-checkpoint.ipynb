# %% [markdown]
# # Preliminaries
# This notebook has the code to make figure 4 in the manuscript.

# %%
from simulation import *
from aesthetics import *
from models import *
from data import *
from analysis import *

import glob
import os as os
import re as re
import pandas as pd

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
mpl.rc('text', usetex=True)
cmap = sns.color_palette("Paired", 10)

# %%
adk_scan = pd.read_pickle('adk-concentration-scan.pickle')

# %%
adk_scan.sort('Directional flux', ascending=False).head(100)
# Out:
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#        Concentration  Directional flux  Driven flux       File  \
# 54141           -0.1         89.404044   282.207746   psiSER41
# 53238           -0.2         89.292724   281.844240   psiSER41
# 52335           -0.3         89.149592   281.382639   psiSER41
# 51432           -0.4         88.966056   280.796712   psiSER41
# 50529           -0.5         88.734870   280.059853   psiSER41
# 49626           -0.6         88.442134   279.131669   psiSER41
# 48723           -0.7         88.075659   277.970144   psiSER41
# 47820           -0.8         87.616836   276.519076   psiSER41
# 46917           -0.9         87.045063   274.713140   psiSER41
# 46014           -1.0         86.334664   272.469329   psiSER41
# 45111           -1.1         85.457174   269.697744   psiSER41
# 44208           -1.2         84.376019   266.285047   psiSER41
# 43305           -1.3         83.053243   262.108841   psiSER41
# 42402           -1.4         81.445298   257.033679   psiSER41
# 41499           -1.5         79.507439   250.918084   psiSER41
# 40596           -1.6         77.195227   243.620680   psiSER41
# 39693           -1.7         74.468177   235.014294   psiSER41
# 38790           -1.8         71.297221   225.007236   psiSER41
# 37887           -1.9         67.670234   213.559900   psiSER41
# 53592           -0.1         64.652512   194.310861  chi2PHE81
# 52689           -0.2         64.549657   193.997531  chi2PHE81
# 51786           -0.3         64.414278   193.588542  chi2PHE81
# 50883           -0.4         64.240921   193.066802  chi2PHE81
# 49980           -0.5         64.019830   192.400838  chi2PHE81
# 49077           -0.6         63.741617   191.563567  chi2PHE81
# 36984           -2.0         63.597062   200.705124   psiSER41
# 48174           -0.7         63.391495   190.511152  chi2PHE81
# 47271           -0.8         62.955801   189.201848  chi2PHE81
# 46368           -0.9         62.413931   187.571595  chi2PHE81
# 45465           -1.0         61.743266   185.556615  chi2PHE81
# ...              ...               ...          ...        ...
# 42769           -1.3         55.333227   156.817628  chi2THR15
# 41866           -1.4         55.226512   156.515597  chi2THR15
# 40963           -1.5         55.092002   156.133624  chi2THR15
# 33725           -2.3         54.934226    90.704103  chi2PHE19
# 40060           -1.6         54.922660   155.652949  chi2THR15
# 39157           -1.7         54.708863   155.048193  chi2THR15
# 38254           -1.8         54.442035   154.291310  chi2THR15
# 35178           -2.2         54.301269   171.368973   psiSER41
# 37351           -1.9         54.109140   153.347839  chi2THR15
# 32822           -2.4         53.933731    89.052438  chi2PHE19
# 36448           -2.0         53.695656   152.175839  chi2THR15
# 37351          31.586556   0.00000   0.000000    15
# 32822          14.652776   0.00004   0.000926    19
# 36448          31.345126   0.00000   0.000000    15
# 40047          51.600109   0.49099  13.069783    81
# 35545          31.046025   0.00000   0.000000    15
# 31919          14.324290   0.00003   0.000902    19
# 34642          30.677538   0.00000   0.000000    15
# 33739          30.225601   0.00000   0.000000    15
# 31016          13.931113   0.00003   0.000874    19
# 39144          49.298664   0.49099  12.470558    81
# 32836          29.675204   0.00000   0.000000    15
# 31933          29.010014   0.00000   0.000000    15
# 30113          13.465798   0.00003   0.000841    19
# 34275          27.993110   1.11099  28.057778    41
# 31030          28.213911   0.00000   0.000000    15
# 38241          46.677763   0.48099  11.788501    81
# 29210          12.922433   0.00003   0.000802    19
# 30127          27.271499   0.00000   0.000000    15
# 37338          43.749482   0.48099  11.027387    81
# 28307          12.297709   0.00003   0.000757    19
# 29224          26.171220   0.00000   0.000000    15
# 46612          22.313157   0.15099   3.316590    12
#
# [100 rows x 8 columns]

# %%
name = 'chi2PHE81'

# %%
this = simulation(data_source = 'adk_md_data')
this.name = name
this.cSubstrate = 10**-3
this.simulate()
this.plot_input()
this.plot_energy()
this.plot_ss()
this.plot_flux()
# Out:
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         +9.99e+00  cycle second**-1
# Peak intrasurface flux    +3.00e+01  cycle second**-1
# Intersurface flux         +6.25e-06  cycle second**-1

# %%
this = simulation(data_source='adk_md_data')
this.name = 'chi2PHE81'
this.cSubstrate = 1e-3
this.simulate()

data = this.unbound_population[1:]
reversed_data = data[::-1]
unbound_averaged = (data + reversed_data) / 2.
# unbound_averaged = np.concatenate(([60], unbound_averaged))

data = this.bound_population[1:]
reversed_data = data[::-1]
bound_averaged = (data + reversed_data) / 2.
# bound_averaged = np.concatenate(([60], bound_averaged))

this = simulation(data_source='manual')
this.cSubstrate = 1e-3
this.unbound_population = unbound_averaged
this.bound_population = bound_averaged
this.C_intersurface = +1.00e+06 
this.offset_factor = 5.7 
this.catalytic_rate = +3.12e+02
this.simulate()
this.plot_input()
this.plot_ss()
this.plot_energy()
this.plot_flux()
# Out:
# Using manual parameters, specify C, offset, and catalytic rate.
# C                         +1.00e+06  second**-1
# D                         +3.00e+12  degrees**2 second**-1
# k_{cat}                   +3.12e+02  second**-1
# [S]                       +1.00e-03  M
# dt                        +1.00e-12  second**-1
# -----------------         ---------  ---------
# Intrasurface flux         -1.78e-04  cycle second**-1
# Peak intrasurface flux    +8.89e+01  cycle second**-1
# Intersurface flux         -5.18e-06  cycle second**-1
