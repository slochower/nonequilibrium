# %%
from simulation import *
from aesthetics import *
from scipy import stats

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Diffusion theory
#
# In general, this relationship is generally valid:
# $$
# \langle x^2 \rangle = dDt
# $$
# where $x$ is the position, $d$ is the dimensionality factor, $D$ is the diffusion coefficient, and $t$ is time over which the mean squared displacment is averaged. In our case, we have an angle $\theta$ instead of a position and the angle is periodic, so we must unroll it. The angle moves only in one dimension, so $d = 2$ and I'm going to write the time interval explicitly as $t + \tau$. So we define the MSD as:
# $$
# \text{MSD} \equiv \langle \left( \theta(t + \tau) - \theta(t) \right)^{2} \rangle = 2D \tau.
# $$

# %% [markdown]
# # Part 1: unroll the angle measurements
#
# We keep track of two things: first, the distance (in angular space) between adjacent measurements and second, the number of times we perform a full cycle in either direction (flips and flops).

# %%
# data = np.genfromtxt('butane-rotational-diffusion/md-data/Langevin-dynamics-10fs-recording/cccc.dat')
prefix = '/home/dslochower/data/projects/nonequilibrium/'
data = np.genfromtxt(prefix + '/md-data/butane-rotational-diffusion/md-data/Langevin-dynamics-10fs-recording-v2/cccc.dat')
distances = np.diff(data[:, 1])

# %%
flips = np.where(distances > 100)[0] # Where the torsion goes from negative to positive, so we subtract 360 for displacement
flops = np.where(distances < -100)[0] # Where the torsion goes from negative to positive, so we add 360 for displacement
print(len(flips))
print(len(flops))
# Out:
# 17216
# 17287

# %% [markdown]
# Here there were 9012 rotations from negative to positive (CCW, I believe) and 9014 rotations from positive to negative (CW). We expect these to be equal because the torsion is undergo *free* diffusion with no biasing potential. Previously, we've verified that the probability of being in any bin (at any angle) is equal.
#
# This is what the negative to positive flip looks like before unrolling th data.

# %%
print(data[flips[0] - 1, 1])
print(data[flips[0], 1])
print(data[flips[0] + 1, 1])
print(data[flips[0] + 2, 1])
# Out:
# -175.3009
# -176.4237
# 179.2425
# 171.9868

# %% [markdown]
# After the angle has rotated through a full cycle (e.g., passing from $-180^\circ$ to $+180^\circ$) we add (or subtract) $360^\circ$ from the following measurements.

# %%
unwrapped_data = np.copy(data)
for subtraction in flips: 
    unwrapped_data[subtraction + 1:, 1] -= 360

# %%
for addition in flops: 
    unwrapped_data[addition + 1:, 1] += 360

# %% [markdown]
# Here is the same data as above, but unrolled. Notice the discontinuity (change of sign) is no longer there.
# Also note that the -164 has changed to +195 (a difference of 360).

# %%
print(unwrapped_data[flips[0] - 1, 1])
print(unwrapped_data[flips[0], 1])
print(unwrapped_data[flips[0] + 1, 1])
print(unwrapped_data[flips[0] + 2, 1])
# Out:
# 184.6991
# 183.5763
# 179.2425
# 171.9868

# %% [markdown]
# Now let's compare the *raw* data and the unrolled data. It's impossible to look at the raw data because the angle is fluctuating so wildly, so I'm only plotting every 10,000 data point!

# %%
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
# fig.subplots_adjust(wspace=0.4)
# ax1.plot(range(1, len(data[:, 1]), 10000), data[::10000, 1])
# ax1.set_title('Raw data', y=1.05)
# ax1.set_ylabel(r'$\theta$ (degrees)')
# ax1.set_xlabel('Time (frames)')

fig, ax2 = plt.subplots(1, 1, figsize=(8, 6))
ax2.plot([i*10*1e-6 for i in range(len(unwrapped_data))], unwrapped_data[:, 1])
ax2.set_title('Unrolled data', y=1.05)
ax2.set_ylabel(r'Continuous $\theta$ (degrees)')
ax2.set_xlabel('Time (ns)')

pretty_plot(fig)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.subplots_adjust(wspace=0.2)
ax1.hist(np.diff(data[:, 1]), bins=20)
ax1.set_title('Raw data step size histogram (with periodicitiy errors)', y=1.05)
ax1.set_ylabel('Count')
ax1.set_xlabel(r'$\theta$ (degrees)')

ax2.hist(np.diff(unwrapped_data[:, 1]), bins=20)
ax2.set_title('Unrolled data step size histogram', y=1.05)
ax2.set_ylabel('Count')
ax2.set_xlabel(r'Continous $\theta$ (degrees)')

# %% [markdown]
# # Part 2: calculate the mean squared displacement for each time interval $\tau$ using the unrolled data

# %%
unwrapped_positions = unwrapped_data[:, 1]

# %%
def compute_msd(trajectory, delta):
    ''' For a given time interval, compute the displacements of the angle. For small time deltas,
    there are many displacements in the trajectory. As the delta gets bigger, there are fewer
    and fewer displacements.'''
    number_measurements = len(trajectory) - delta
    print('Computing mean of {} measurements'.format(number_measurements))
    displacements = np.empty((number_measurements))
    for time in range(number_measurements):
        displacements[time] = trajectory[time + delta] - trajectory[time]
    return np.mean(displacements**2), stats.sem(displacements**2)

# %%
delays = np.arange(10000, len(unwrapped_positions) - 1, 10000)
MSDs = np.empty((len(delays)))
SEMs = np.empty((len(delays)))
for delay in delays:
    MSDs[np.where(delays==delay)[0]], SEMs[np.where(delays==delay)[0]] = compute_msd(unwrapped_positions, delay)
# Out:
# Computing mean of 4990000 measurements
# Computing mean of 4980000 measurements
# Computing mean of 4970000 measurements
# Computing mean of 4960000 measurements
# Computing mean of 4950000 measurements
# Computing mean of 4940000 measurements
# Computing mean of 4930000 measurements
# Computing mean of 4920000 measurements
# Computing mean of 4910000 measurements
# Computing mean of 4900000 measurements
# Computing mean of 4890000 measurements
# Computing mean of 4880000 measurements
# Computing mean of 4870000 measurements
# Computing mean of 4860000 measurements
# Computing mean of 4850000 measurements
# Computing mean of 4840000 measurements
# Computing mean of 4830000 measurements
# Computing mean of 4820000 measurements
# Computing mean of 4810000 measurements
# Computing mean of 4800000 measurements
# Computing mean of 4790000 measurements
# Computing mean of 4780000 measurements
# Computing mean of 4770000 measurements
# Computing mean of 4760000 measurements
# Computing mean of 4750000 measurements
# Computing mean of 4740000 measurements
# Computing mean of 4730000 measurements
# Computing mean of 4720000 measurements
# Computing mean of 4710000 measurements
# Computing mean of 4700000 measurements
# Computing mean of 4690000 measurements
# Computing mean of 4680000 measurements
# Computing mean of 4670000 measurements
# Computing mean of 4660000 measurements
# Computing mean of 4650000 measurements
# Computing mean of 4640000 measurements
# Computing mean of 4630000 measurements
# Computing mean of 4620000 measurements
# Computing mean of 4610000 measurements
# Computing mean of 4600000 measurements
# Computing mean of 4590000 measurements
# Computing mean of 4580000 measurements
# Computing mean of 4570000 measurements
# Computing mean of 4560000 measurements
# Computing mean of 4550000 measurements
# Computing mean of 4540000 measurements
# Computing mean of 4530000 measurements
# Computing mean of 4520000 measurements
# Computing mean of 4510000 measurements
# Computing mean of 4500000 measurements
# Computing mean of 4490000 measurements
# Computing mean of 4480000 measurements
# Computing mean of 4470000 measurements
# Computing mean of 4460000 measurements
# Computing mean of 4450000 measurements
# Computing mean of 4440000 measurements
# Computing mean of 4430000 measurements
# Computing mean of 4420000 measurements
# Computing mean of 4410000 measurements
# Computing mean of 4400000 measurements
# Computing mean of 4390000 measurements
# Computing mean of 4380000 measurements
# Computing mean of 4370000 measurements
# Computing mean of 4360000 measurements
# Computing mean of 4350000 measurements
# Computing mean of 4340000 measurements
# Computing mean of 4330000 measurements
# Computing mean of 4320000 measurements
# Computing mean of 4310000 measurements
# Computing mean of 4300000 measurements
# Computing mean of 4290000 measurements
# Computing mean of 4280000 measurements
# Computing mean of 4270000 measurements
# Computing mean of 4260000 measurements
# Computing mean of 4250000 measurements
# Computing mean of 4240000 measurements
# Computing mean of 4230000 measurements
# Computing mean of 4220000 measurements
# Computing mean of 4210000 measurements
# Computing mean of 4200000 measurements
# Computing mean of 4190000 measurements
# Computing mean of 4180000 measurements
# Computing mean of 4170000 measurements
# Computing mean of 4160000 measurements
# Computing mean of 4150000 measurements
# Computing mean of 4140000 measurements
# Computing mean of 4130000 measurements
# Computing mean of 4120000 measurements
# Computing mean of 4110000 measurements
# Computing mean of 4100000 measurements
# Computing mean of 4090000 measurements
# Computing mean of 4080000 measurements
# Computing mean of 4070000 measurements
# Computing mean of 4060000 measurements
# Computing mean of 4050000 measurements
# Computing mean of 4040000 measurements
# Computing mean of 4030000 measurements
# Computing mean of 4020000 measurements
# Computing mean of 4010000 measurements
# Computing mean of 4000000 measurements
# Computing mean of 3990000 measurements
# Computing mean of 3980000 measurements
# Computing mean of 3970000 measurements
# Computing mean of 3960000 measurements
# Computing mean of 3950000 measurements
# Computing mean of 3940000 measurements
# Computing mean of 3930000 measurements
# Computing mean of 3920000 measurements
# Computing mean of 3910000 measurements
# Computing mean of 3900000 measurements
# Computing mean of 3890000 measurements
# Computing mean of 3880000 measurements
# Computing mean of 3870000 measurements
# Computing mean of 3860000 measurements
# Computing mean of 3850000 measurements
# Computing mean of 3840000 measurements
# Computing mean of 3830000 measurements
# Computing mean of 3820000 measurements
# Computing mean of 3810000 measurements
# Computing mean of 3800000 measurements
# Computing mean of 3790000 measurements
# Computing mean of 3780000 measurements
# Computing mean of 3770000 measurements
# Computing mean of 3760000 measurements
# Computing mean of 3750000 measurements
# Computing mean of 3740000 measurements
# Computing mean of 3730000 measurements
# Computing mean of 3720000 measurements
# Computing mean of 3710000 measurements
# Computing mean of 3700000 measurements
# Computing mean of 3690000 measurements
# Computing mean of 3680000 measurements
# Computing mean of 3670000 measurements
# Computing mean of 3660000 measurements
# Computing mean of 3650000 measurements
# Computing mean of 3640000 measurements
# Computing mean of 3630000 measurements
# Computing mean of 3620000 measurements
# Computing mean of 3610000 measurements
# Computing mean of 3600000 measurements
# Computing mean of 3590000 measurements
# Computing mean of 3580000 measurements
# Computing mean of 3570000 measurements
# Computing mean of 3560000 measurements
# Computing mean of 3550000 measurements
# Computing mean of 3540000 measurements
# Computing mean of 3530000 measurements
# Computing mean of 3520000 measurements
# Computing mean of 3510000 measurements
# Computing mean of 3500000 measurements
# Computing mean of 3490000 measurements
# Computing mean of 3480000 measurements
# Computing mean of 3470000 measurements
# Computing mean of 3460000 measurements
# Computing mean of 3450000 measurements
# Computing mean of 3440000 measurements
# Computing mean of 3430000 measurements
# Computing mean of 3420000 measurements
# Computing mean of 3410000 measurements
# Computing mean of 3400000 measurements
# Computing mean of 3390000 measurements
# Computing mean of 3380000 measurements
# Computing mean of 3370000 measurements
# Computing mean of 3360000 measurements
# Computing mean of 3350000 measurements
# Computing mean of 3340000 measurements
# Computing mean of 3330000 measurements
# Computing mean of 3320000 measurements
# Computing mean of 3310000 measurements
# Computing mean of 3300000 measurements
# Computing mean of 3290000 measurements
# Computing mean of 3280000 measurements
# Computing mean of 3270000 measurements
# Computing mean of 3260000 measurements
# Computing mean of 3250000 measurements
# Computing mean of 3240000 measurements
# Computing mean of 3230000 measurements
# Computing mean of 3220000 measurements
# Computing mean of 3210000 measurements
# Computing mean of 3200000 measurements
# Computing mean of 3190000 measurements
# Computing mean of 3180000 measurements
# Computing mean of 3170000 measurements
# Computing mean of 3160000 measurements
# Computing mean of 3150000 measurements
# Computing mean of 3140000 measurements
# Computing mean of 3130000 measurements
# Computing mean of 3120000 measurements
# Computing mean of 3110000 measurements
# Computing mean of 3100000 measurements
# Computing mean of 3090000 measurements
# Computing mean of 3080000 measurements
# Computing mean of 3070000 measurements
# Computing mean of 3060000 measurements
# Computing mean of 3050000 measurements
# Computing mean of 3040000 measurements
# Computing mean of 3030000 measurements
# Computing mean of 3020000 measurements
# Computing mean of 3010000 measurements
# Computing mean of 3000000 measurements
# Computing mean of 2990000 measurements
# Computing mean of 2980000 measurements
# Computing mean of 2970000 measurements
# Computing mean of 2960000 measurements
# Computing mean of 2950000 measurements
# Computing mean of 2940000 measurements
# Computing mean of 2930000 measurements
# Computing mean of 2920000 measurements
# Computing mean of 2910000 measurements
# Computing mean of 2900000 measurements
# Computing mean of 2890000 measurements
# Computing mean of 2880000 measurements
# Computing mean of 2870000 measurements
# Computing mean of 2860000 measurements
# Computing mean of 2850000 measurements
# Computing mean of 2840000 measurements
# Computing mean of 2830000 measurements
# Computing mean of 2820000 measurements
# Computing mean of 2810000 measurements
# Computing mean of 2800000 measurements
# Computing mean of 2790000 measurements
# Computing mean of 2780000 measurements
# Computing mean of 2770000 measurements
# Computing mean of 2760000 measurements
# Computing mean of 2750000 measurements
# Computing mean of 2740000 measurements
# Computing mean of 2730000 measurements
# Computing mean of 2720000 measurements
# Computing mean of 2710000 measurements
# Computing mean of 2700000 measurements
# Computing mean of 2690000 measurements
# Computing mean of 2680000 measurements
# Computing mean of 2670000 measurements
# Computing mean of 2660000 measurements
# Computing mean of 2650000 measurements
# Computing mean of 2640000 measurements
# Computing mean of 2630000 measurements
# Computing mean of 2620000 measurements
# Computing mean of 2610000 measurements
# Computing mean of 2600000 measurements
# Computing mean of 2590000 measurements
# Computing mean of 2580000 measurements
# Computing mean of 2570000 measurements
# Computing mean of 2560000 measurements
# Computing mean of 2550000 measurements
# Computing mean of 2540000 measurements
# Computing mean of 2530000 measurements
# Computing mean of 2520000 measurements
# Computing mean of 2510000 measurements
# Computing mean of 2500000 measurements
# Computing mean of 2490000 measurements
# Computing mean of 2480000 measurements
# Computing mean of 2470000 measurements
# Computing mean of 2460000 measurements
# Computing mean of 2450000 measurements
# Computing mean of 2440000 measurements
# Computing mean of 2430000 measurements
# Computing mean of 2420000 measurements
# Computing mean of 2410000 measurements
# Computing mean of 2400000 measurements
# Computing mean of 2390000 measurements
# Computing mean of 2380000 measurements
# Computing mean of 2370000 measurements
# Computing mean of 2360000 measurements
# Computing mean of 2350000 measurements
# Computing mean of 2340000 measurements
# Computing mean of 2330000 measurements
# Computing mean of 2320000 measurements
# Computing mean of 2310000 measurements
# Computing mean of 2300000 measurements
# Computing mean of 2290000 measurements
# Computing mean of 2280000 measurements
# Computing mean of 2270000 measurements
# Computing mean of 2260000 measurements
# Computing mean of 2250000 measurements
# Computing mean of 2240000 measurements
# Computing mean of 2230000 measurements
# Computing mean of 2220000 measurements
# Computing mean of 2210000 measurements
# Computing mean of 2200000 measurements
# Computing mean of 2190000 measurements
# Computing mean of 2180000 measurements
# Computing mean of 2170000 measurements
# Computing mean of 2160000 measurements
# Computing mean of 2150000 measurements
# Computing mean of 2140000 measurements
# Computing mean of 2130000 measurements
# Computing mean of 2120000 measurements
# Computing mean of 2110000 measurements
# Computing mean of 2100000 measurements
# Computing mean of 2090000 measurements
# Computing mean of 2080000 measurements
# Computing mean of 2070000 measurements
# Computing mean of 2060000 measurements
# Computing mean of 2050000 measurements
# Computing mean of 2040000 measurements
# Computing mean of 2030000 measurements
# Computing mean of 2020000 measurements
# Computing mean of 2010000 measurements
# Computing mean of 2000000 measurements
# Computing mean of 1990000 measurements
# Computing mean of 1980000 measurements
# Computing mean of 1970000 measurements
# Computing mean of 1960000 measurements
# Computing mean of 1950000 measurements
# Computing mean of 1940000 measurements
# Computing mean of 1930000 measurements
# Computing mean of 1920000 measurements
# Computing mean of 1910000 measurements
# Computing mean of 1900000 measurements
# Computing mean of 1890000 measurements
# Computing mean of 1880000 measurements
# Computing mean of 1870000 measurements
# Computing mean of 1860000 measurements
# Computing mean of 1850000 measurements
# Computing mean of 1840000 measurements
# Computing mean of 1830000 measurements
# Computing mean of 1820000 measurements
# Computing mean of 1810000 measurements
# Computing mean of 1800000 measurements
# Computing mean of 1790000 measurements
# Computing mean of 1780000 measurements
# Computing mean of 1770000 measurements
# Computing mean of 1760000 measurements
# Computing mean of 1750000 measurements
# Computing mean of 1740000 measurements
# Computing mean of 1730000 measurements
# Computing mean of 1720000 measurements
# Computing mean of 1710000 measurements
# Computing mean of 1700000 measurements
# Computing mean of 1690000 measurements
# Computing mean of 1680000 measurements
# Computing mean of 1670000 measurements
# Computing mean of 1660000 measurements
# Computing mean of 1650000 measurements
# Computing mean of 1640000 measurements
# Computing mean of 1630000 measurements
# Computing mean of 1620000 measurements
# Computing mean of 1610000 measurements
# Computing mean of 1600000 measurements
# Computing mean of 1590000 measurements
# Computing mean of 1580000 measurements
# Computing mean of 1570000 measurements
# Computing mean of 1560000 measurements
# Computing mean of 1550000 measurements
# Computing mean of 1540000 measurements
# Computing mean of 1530000 measurements
# Computing mean of 1520000 measurements
# Computing mean of 1510000 measurements
# Computing mean of 1500000 measurements
# Computing mean of 1490000 measurements
# Computing mean of 1480000 measurements
# Computing mean of 1470000 measurements
# Computing mean of 1460000 measurements
# Computing mean of 1450000 measurements
# Computing mean of 1440000 measurements
# Computing mean of 1430000 measurements
# Computing mean of 1420000 measurements
# Computing mean of 1410000 measurements
# Computing mean of 1400000 measurements
# Computing mean of 1390000 measurements
# Computing mean of 1380000 measurements
# Computing mean of 1370000 measurements
# Computing mean of 1360000 measurements
# Computing mean of 1350000 measurements
# Computing mean of 1340000 measurements
# Computing mean of 1330000 measurements
# Computing mean of 1320000 measurements
# Computing mean of 1310000 measurements
# Computing mean of 1300000 measurements
# Computing mean of 1290000 measurements
# Computing mean of 1280000 measurements
# Computing mean of 1270000 measurements
# Computing mean of 1260000 measurements
# Computing mean of 1250000 measurements
# Computing mean of 1240000 measurements
# Computing mean of 1230000 measurements
# Computing mean of 1220000 measurements
# Computing mean of 1210000 measurements
# Computing mean of 1200000 measurements
# Computing mean of 1190000 measurements
# Computing mean of 1180000 measurements
# Computing mean of 1170000 measurements
# Computing mean of 1160000 measurements
# Computing mean of 1150000 measurements
# Computing mean of 1140000 measurements
# Computing mean of 1130000 measurements
# Computing mean of 1120000 measurements
# Computing mean of 1110000 measurements
# Computing mean of 1100000 measurements
# Computing mean of 1090000 measurements
# Computing mean of 1080000 measurements
# Computing mean of 1070000 measurements
# Computing mean of 1060000 measurements
# Computing mean of 1050000 measurements
# Computing mean of 1040000 measurements
# Computing mean of 1030000 measurements
# Computing mean of 1020000 measurements
# Computing mean of 1010000 measurements
# Computing mean of 1000000 measurements
# Computing mean of 990000 measurements
# Computing mean of 980000 measurements
# Computing mean of 970000 measurements
# Computing mean of 960000 measurements
# Computing mean of 950000 measurements
# Computing mean of 940000 measurements
# Computing mean of 930000 measurements
# Computing mean of 920000 measurements
# Computing mean of 910000 measurements
# Computing mean of 900000 measurements
# Computing mean of 890000 measurements
# Computing mean of 880000 measurements
# Computing mean of 870000 measurements
# Computing mean of 860000 measurements
# Computing mean of 850000 measurements
# Computing mean of 840000 measurements
# Computing mean of 830000 measurements
# Computing mean of 820000 measurements
# Computing mean of 810000 measurements
# Computing mean of 800000 measurements
# Computing mean of 790000 measurements
# Computing mean of 780000 measurements
# Computing mean of 770000 measurements
# Computing mean of 760000 measurements
# Computing mean of 750000 measurements
# Computing mean of 740000 measurements
# Computing mean of 730000 measurements
# Computing mean of 720000 measurements
# Computing mean of 710000 measurements
# Computing mean of 700000 measurements
# Computing mean of 690000 measurements
# Computing mean of 680000 measurements
# Computing mean of 670000 measurements
# Computing mean of 660000 measurements
# Computing mean of 650000 measurements
# Computing mean of 640000 measurements
# Computing mean of 630000 measurements
# Computing mean of 620000 measurements
# Computing mean of 610000 measurements
# Computing mean of 600000 measurements
# Computing mean of 590000 measurements
# Computing mean of 580000 measurements
# Computing mean of 570000 measurements
# Computing mean of 560000 measurements
# Computing mean of 550000 measurements
# Computing mean of 540000 measurements
# Computing mean of 530000 measurements
# Computing mean of 520000 measurements
# Computing mean of 510000 measurements
# Computing mean of 500000 measurements
# Computing mean of 490000 measurements
# Computing mean of 480000 measurements
# Computing mean of 470000 measurements
# Computing mean of 460000 measurements
# Computing mean of 450000 measurements
# Computing mean of 440000 measurements
# Computing mean of 430000 measurements
# Computing mean of 420000 measurements
# Computing mean of 410000 measurements
# Computing mean of 400000 measurements
# Computing mean of 390000 measurements
# Computing mean of 380000 measurements
# Computing mean of 370000 measurements
# Computing mean of 360000 measurements
# Computing mean of 350000 measurements
# Computing mean of 340000 measurements
# Computing mean of 330000 measurements
# Computing mean of 320000 measurements
# Computing mean of 310000 measurements
# Computing mean of 300000 measurements
# Computing mean of 290000 measurements
# Computing mean of 280000 measurements
# Computing mean of 270000 measurements
# Computing mean of 260000 measurements
# Computing mean of 250000 measurements
# Computing mean of 240000 measurements
# Computing mean of 230000 measurements
# Computing mean of 220000 measurements
# Computing mean of 210000 measurements
# Computing mean of 200000 measurements
# Computing mean of 190000 measurements
# Computing mean of 180000 measurements
# Computing mean of 170000 measurements
# Computing mean of 160000 measurements
# Computing mean of 150000 measurements
# Computing mean of 140000 measurements
# Computing mean of 130000 measurements
# Computing mean of 120000 measurements
# Computing mean of 110000 measurements
# Computing mean of 100000 measurements
# Computing mean of 90000 measurements
# Computing mean of 80000 measurements
# Computing mean of 70000 measurements
# Computing mean of 60000 measurements
# Computing mean of 50000 measurements
# Computing mean of 40000 measurements
# Computing mean of 30000 measurements
# Computing mean of 20000 measurements
# Computing mean of 10000 measurements

# %%
times = delays * 10**-5
fig, ax1 = plt.subplots(1, 1, figsize=(8, 6))
ax1.errorbar(times, MSDs, yerr=100*SEMs)
ax1.set_ylabel(r'$\left\langle \left(\theta(\tau + t) - \theta(t) \right) ^2 \right\rangle$ (degrees$^2$)')
ax1.set_xlabel(r'Time (ns)')
pretty_plot(fig, scientific=False)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(times,
                                                               MSDs)
print('{0:2.2e} +/- {1:2.2e}'.format(slope / 2, std_err / 2))

times = delays * 10**-5
fig, ax1 = plt.subplots(1, 1, figsize=(8, 6))
ax1.errorbar(times, MSDs, yerr=100*SEMs)
ax1.plot(times, times * slope + intercept, c='k', ls='--', lw=2, label='Fit')
ax1.set_ylabel(r'$\left\langle \left(\theta(\tau + t) - \theta(t) \right) ^2 \right\rangle$ (degrees$^2$)')
ax1.set_xlabel(r'Time (ns)')
ax1.legend(loc=2)
pretty_plot(fig, scientific=False)
# Out:
# 3.13e+06 +/- 1.06e+05

# %% [markdown]
# When plotting $\langle \theta(\tau)^2 \rangle$, the slope of the plots (on the left) should be $2D$ yet cleary they are not linear. It's typical to take the middle 80% of the data to calculate the slope, because the statistics are nosiy when the time dela is a very large part or very small part of the trajectory.

# %%
ten_percent = 0.1*len(delays)
ninety_percent = 0.9*len(delays)
slope, intercept, r_value, p_value, std_err = stats.linregress(delays[ten_percent:ninety_percent]*10**-14,
                                                               MSDs[ten_percent:ninety_percent])
# Out:
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   app.launch_new_instance()
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
# Femtosecond is 10**-15
# Each frame is 10 fs = 10**-14
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.subplots_adjust(wspace=0.2)
ax1.errorbar(delays*10**-14, MSDs, yerr=SEMs)
ax1.plot(delays[ten_percent:ninety_percent]*10**-14, MSDs[ten_percent:ninety_percent], c='r', label='Data used for fit')
ax1.set_ylabel(r'$\langle \theta(\tau)^2 \rangle$ (degrees$^2$)')
ax1.set_xlabel(r'Time delay $\tau$ (seconds)')
ax1.legend()

ax2.errorbar(delays*10**-14, MSDs, yerr=SEMs)
ax2.plot(delays[ten_percent:ninety_percent]*10**-14, slope*delays[ten_percent:ninety_percent]*10**-14+intercept, c='g', ls='-', label='Linear fit')
ax2.plot(delays[0:ten_percent]*10**-14, slope*delays[0:ten_percent]*10**-14+intercept, c='g', ls='--')
ax2.plot(delays[ninety_percent:]*10**-14, slope*delays[ninety_percent:]*10**-14+intercept, c='g', ls='--')
ax2.set_ylabel(r'$\langle \theta(\tau)^2 \rangle$ (degrees$^2$)')
ax2.set_xlabel(r'Time delay $\tau$ (seconds)')
ax2.ticklabel_format(style='sci', axis='both', scilimits=(0,0))
ax2.xaxis.major.formatter._useMathText = True
ax2.legend()
# Out:
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:12: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:13: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
print(slope)
print(slope/2)
# Out:
# -5.61100568547e+14
# -2.80550284274e+14

# %% [markdown]
# We have $5.4 \times 10^{13}$ (degrees$^2$/second) = $2D$, so D = $2.7 \times 10^{13}$ (degrees$^2$/second). This is not that much smaller than `C_intrasurface`!
#
# From the other notebook, we determined the probability to go left (or right) into another bin (6 degrees) in 10 fs is 0.2143 (0.5446 to stay in the same bin). Thus, we wrote:
# $$
# \Delta P_i = -2C \Delta t
# (1 - 0.5446) = -2C(1 \times 10^{-14} \text{second})
# C = 2.28 \times 10^{13} \text{second}^{-1}
# $$
#
# I believe that value represents the bin to bin transition rate for *6 degree bins* and thus, I would modify the above to like thus:
# $$
# \begin{align}
# C &= 2.28 \times 10^{13}  \cdot \text{second}^{-1} \times \text{6 degrees} \quad \text{and, so} \\
# C_\text{intrasurface} &= 3.8 \times 10^{12} \text{degrees} \cdot \text{second}^{-1}
# \end{align}
# $$
#
# Thus, $D =  2.7 \times 10^{13}$ (degrees$^2$/second) and $C_\text{intrasurface} = 3.8 \times 10^{12} \text{degrees} \cdot \text{second}^{-1}$. Not sure about units.

# %% [markdown]
# # A new set of data!

# %%
data = np.genfromtxt('../butane-rotational-diffusion/Langevin-dynamics-10fs-recording/cccc.dat')
distances = np.diff(data[:, 1])

# %%
flips = np.where(distances > 100)[0] # Where the torsion goes from negative to positive, so we subtract 360 for displacement
flops = np.where(distances < -100)[0] # Where the torsion goes from negative to positive, so we add 360 for displacement
print(len(flips))
print(len(flops))
unwrapped_data = np.copy(data)
# Out:
# 16414
# 16437

# %%
for subtraction in flips: 
    unwrapped_data[subtraction + 1:, 1] -= 360
for addition in flops: 
    unwrapped_data[addition + 1:, 1] += 360

# %%
rng = 1000

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.subplots_adjust(wspace=0.2)
ax1.plot(range(len(data[0:rng, 1])), data[0:rng, 1])
ax1.set_title('Raw data', y=1.05)
ax1.set_ylabel(r'$\theta$ (degrees)')
ax1.set_xlabel('Time (frames)')

ax2.plot(range(len(unwrapped_data[0:rng])), unwrapped_data[0:rng, 1])
ax2.set_title('Unrolled data', y=1.05)
ax2.set_ylabel(r'Continuous $\theta$ (degrees)')
ax2.set_xlabel('Time (frames)')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.subplots_adjust(wspace=0.2)
ax1.hist(np.diff(data[0:rng, 1]), bins=20)
ax1.set_title('Raw data step size histogram (with periodicitiy errors)', y=1.05)
ax1.set_ylabel('Count')
ax1.set_xlabel(r'$\theta$ (degrees)')

ax2.hist(np.diff(unwrapped_data[0:rng, 1]), bins=20)
ax2.set_title('Unrolled data step size histogram', y=1.05)
ax2.set_ylabel('Count')
ax2.set_xlabel(r'Continous $\theta$ (degrees)')

# %%
unwrapped_positions = unwrapped_data[:, 1]

# %%
delays = np.arange(10000, len(unwrapped_positions) - 1, 10000)
MSDs = np.empty((len(delays)))
SEMs = np.empty((len(delays)))
for delay in delays:
    MSDs[np.where(delays==delay)[0]], SEMs[np.where(delays==delay)[0]] = compute_msd(unwrapped_positions, delay)
# Out:
# Computing mean of 4990000 measurements
# Computing mean of 4980000 measurements
# Computing mean of 4970000 measurements
# Computing mean of 4960000 measurements
# Computing mean of 4950000 measurements
# Computing mean of 4940000 measurements
# Computing mean of 4930000 measurements
# Computing mean of 4920000 measurements
# Computing mean of 4910000 measurements
# Computing mean of 4900000 measurements
# Computing mean of 4890000 measurements
# Computing mean of 4880000 measurements
# Computing mean of 4870000 measurements
# Computing mean of 4860000 measurements
# Computing mean of 4850000 measurements
# Computing mean of 4840000 measurements
# Computing mean of 4830000 measurements
# Computing mean of 4820000 measurements
# Computing mean of 4810000 measurements
# Computing mean of 4800000 measurements
# Computing mean of 4790000 measurements
# Computing mean of 4780000 measurements
# Computing mean of 4770000 measurements
# Computing mean of 4760000 measurements
# Computing mean of 4750000 measurements
# Computing mean of 4740000 measurements
# Computing mean of 4730000 measurements
# Computing mean of 4720000 measurements
# Computing mean of 4710000 measurements
# Computing mean of 4700000 measurements
# Computing mean of 4690000 measurements
# Computing mean of 4680000 measurements
# Computing mean of 4670000 measurements
# Computing mean of 4660000 measurements
# Computing mean of 4650000 measurements
# Computing mean of 4640000 measurements
# Computing mean of 4630000 measurements
# Computing mean of 4620000 measurements
# Computing mean of 4610000 measurements
# Computing mean of 4600000 measurements
# Computing mean of 4590000 measurements
# Computing mean of 4580000 measurements
# Computing mean of 4570000 measurements
# Computing mean of 4560000 measurements
# Computing mean of 4550000 measurements
# Computing mean of 4540000 measurements
# Computing mean of 4530000 measurements
# Computing mean of 4520000 measurements
# Computing mean of 4510000 measurements
# Computing mean of 4500000 measurements
# Computing mean of 4490000 measurements
# Computing mean of 4480000 measurements
# Computing mean of 4470000 measurements
# Computing mean of 4460000 measurements
# Computing mean of 4450000 measurements
# Computing mean of 4440000 measurements
# Computing mean of 4430000 measurements
# Computing mean of 4420000 measurements
# Computing mean of 4410000 measurements
# Computing mean of 4400000 measurements
# Computing mean of 4390000 measurements
# Computing mean of 4380000 measurements
# Computing mean of 4370000 measurements
# Computing mean of 4360000 measurements
# Computing mean of 4350000 measurements
# Computing mean of 4340000 measurements
# Computing mean of 4330000 measurements
# Computing mean of 4320000 measurements
# Computing mean of 4310000 measurements
# Computing mean of 4300000 measurements
# Computing mean of 4290000 measurements
# Computing mean of 4280000 measurements
# Computing mean of 4270000 measurements
# Computing mean of 4260000 measurements
# Computing mean of 4250000 measurements
# Computing mean of 4240000 measurements
# Computing mean of 4230000 measurements
# Computing mean of 4220000 measurements
# Computing mean of 4210000 measurements
# Computing mean of 4200000 measurements
# Computing mean of 4190000 measurements
# Computing mean of 4180000 measurements
# Computing mean of 4170000 measurements
# Computing mean of 4160000 measurements
# Computing mean of 4150000 measurements
# Computing mean of 4140000 measurements
# Computing mean of 4130000 measurements
# Computing mean of 4120000 measurements
# Computing mean of 4110000 measurements
# Computing mean of 4100000 measurements
# Computing mean of 4090000 measurements
# Computing mean of 4080000 measurements
# Computing mean of 4070000 measurements
# Computing mean of 4060000 measurements
# Computing mean of 4050000 measurements
# Computing mean of 4040000 measurements
# Computing mean of 4030000 measurements
# Computing mean of 4020000 measurements
# Computing mean of 4010000 measurements
# Computing mean of 4000000 measurements
# Computing mean of 3990000 measurements
# Computing mean of 3980000 measurements
# Computing mean of 3970000 measurements
# Computing mean of 3960000 measurements
# Computing mean of 3950000 measurements
# Computing mean of 3940000 measurements
# Computing mean of 3930000 measurements
# Computing mean of 3920000 measurements
# Computing mean of 3910000 measurements
# Computing mean of 3900000 measurements
# Computing mean of 3890000 measurements
# Computing mean of 3880000 measurements
# Computing mean of 3870000 measurements
# Computing mean of 3860000 measurements
# Computing mean of 3850000 measurements
# Computing mean of 3840000 measurements
# Computing mean of 3830000 measurements
# Computing mean of 3820000 measurements
# Computing mean of 3810000 measurements
# Computing mean of 3800000 measurements
# Computing mean of 3790000 measurements
# Computing mean of 3780000 measurements
# Computing mean of 3770000 measurements
# Computing mean of 3760000 measurements
# Computing mean of 3750000 measurements
# Computing mean of 3740000 measurements
# Computing mean of 3730000 measurements
# Computing mean of 3720000 measurements
# Computing mean of 3710000 measurements
# Computing mean of 3700000 measurements
# Computing mean of 3690000 measurements
# Computing mean of 3680000 measurements
# Computing mean of 3670000 measurements
# Computing mean of 3660000 measurements
# Computing mean of 3650000 measurements
# Computing mean of 3640000 measurements
# Computing mean of 3630000 measurements
# Computing mean of 3620000 measurements
# Computing mean of 3610000 measurements
# Computing mean of 3600000 measurements
# Computing mean of 3590000 measurements
# Computing mean of 3580000 measurements
# Computing mean of 3570000 measurements
# Computing mean of 3560000 measurements
# Computing mean of 3550000 measurements
# Computing mean of 3540000 measurements
# Computing mean of 3530000 measurements
# Computing mean of 3520000 measurements
# Computing mean of 3510000 measurements
# Computing mean of 3500000 measurements
# Computing mean of 3490000 measurements
# Computing mean of 3480000 measurements
# Computing mean of 3470000 measurements
# Computing mean of 3460000 measurements
# Computing mean of 3450000 measurements
# Computing mean of 3440000 measurements
# Computing mean of 3430000 measurements
# Computing mean of 3420000 measurements
# Computing mean of 3410000 measurements
# Computing mean of 3400000 measurements
# Computing mean of 3390000 measurements
# Computing mean of 3380000 measurements
# Computing mean of 3370000 measurements
# Computing mean of 3360000 measurements
# Computing mean of 3350000 measurements
# Computing mean of 3340000 measurements
# Computing mean of 3330000 measurements
# Computing mean of 3320000 measurements
# Computing mean of 3310000 measurements
# Computing mean of 3300000 measurements
# Computing mean of 3290000 measurements
# Computing mean of 3280000 measurements
# Computing mean of 3270000 measurements
# Computing mean of 3260000 measurements
# Computing mean of 3250000 measurements
# Computing mean of 3240000 measurements
# Computing mean of 3230000 measurements
# Computing mean of 3220000 measurements
# Computing mean of 3210000 measurements
# Computing mean of 3200000 measurements
# Computing mean of 3190000 measurements
# Computing mean of 3180000 measurements
# Computing mean of 3170000 measurements
# Computing mean of 3160000 measurements
# Computing mean of 3150000 measurements
# Computing mean of 3140000 measurements
# Computing mean of 3130000 measurements
# Computing mean of 3120000 measurements
# Computing mean of 3110000 measurements
# Computing mean of 3100000 measurements
# Computing mean of 3090000 measurements
# Computing mean of 3080000 measurements
# Computing mean of 3070000 measurements
# Computing mean of 3060000 measurements
# Computing mean of 3050000 measurements
# Computing mean of 3040000 measurements
# Computing mean of 3030000 measurements
# Computing mean of 3020000 measurements
# Computing mean of 3010000 measurements
# Computing mean of 3000000 measurements
# Computing mean of 2990000 measurements
# Computing mean of 2980000 measurements
# Computing mean of 2970000 measurements
# Computing mean of 2960000 measurements
# Computing mean of 2950000 measurements
# Computing mean of 2940000 measurements
# Computing mean of 2930000 measurements
# Computing mean of 2920000 measurements
# Computing mean of 2910000 measurements
# Computing mean of 2900000 measurements
# Computing mean of 2890000 measurements
# Computing mean of 2880000 measurements
# Computing mean of 2870000 measurements
# Computing mean of 2860000 measurements
# Computing mean of 2850000 measurements
# Computing mean of 2840000 measurements
# Computing mean of 2830000 measurements
# Computing mean of 2820000 measurements
# Computing mean of 2810000 measurements
# Computing mean of 2800000 measurements
# Computing mean of 2790000 measurements
# Computing mean of 2780000 measurements
# Computing mean of 2770000 measurements
# Computing mean of 2760000 measurements
# Computing mean of 2750000 measurements
# Computing mean of 2740000 measurements
# Computing mean of 2730000 measurements
# Computing mean of 2720000 measurements
# Computing mean of 2710000 measurements
# Computing mean of 2700000 measurements
# Computing mean of 2690000 measurements
# Computing mean of 2680000 measurements
# Computing mean of 2670000 measurements
# Computing mean of 2660000 measurements
# Computing mean of 2650000 measurements
# Computing mean of 2640000 measurements
# Computing mean of 2630000 measurements
# Computing mean of 2620000 measurements
# Computing mean of 2610000 measurements
# Computing mean of 2600000 measurements
# Computing mean of 2590000 measurements
# Computing mean of 2580000 measurements
# Computing mean of 2570000 measurements
# Computing mean of 2560000 measurements
# Computing mean of 2550000 measurements
# Computing mean of 2540000 measurements
# Computing mean of 2530000 measurements
# Computing mean of 2520000 measurements
# Computing mean of 2510000 measurements
# Computing mean of 2500000 measurements
# Computing mean of 2490000 measurements
# Computing mean of 2480000 measurements
# Computing mean of 2470000 measurements
# Computing mean of 2460000 measurements
# Computing mean of 2450000 measurements
# Computing mean of 2440000 measurements
# Computing mean of 2430000 measurements
# Computing mean of 2420000 measurements
# Computing mean of 2410000 measurements
# Computing mean of 2400000 measurements
# Computing mean of 2390000 measurements
# Computing mean of 2380000 measurements
# Computing mean of 2370000 measurements
# Computing mean of 2360000 measurements
# Computing mean of 2350000 measurements
# Computing mean of 2340000 measurements
# Computing mean of 2330000 measurements
# Computing mean of 2320000 measurements
# Computing mean of 2310000 measurements
# Computing mean of 2300000 measurements
# Computing mean of 2290000 measurements
# Computing mean of 2280000 measurements
# Computing mean of 2270000 measurements
# Computing mean of 2260000 measurements
# Computing mean of 2250000 measurements
# Computing mean of 2240000 measurements
# Computing mean of 2230000 measurements
# Computing mean of 2220000 measurements
# Computing mean of 2210000 measurements
# Computing mean of 2200000 measurements
# Computing mean of 2190000 measurements
# Computing mean of 2180000 measurements
# Computing mean of 2170000 measurements
# Computing mean of 2160000 measurements
# Computing mean of 2150000 measurements
# Computing mean of 2140000 measurements
# Computing mean of 2130000 measurements
# Computing mean of 2120000 measurements
# Computing mean of 2110000 measurements
# Computing mean of 2100000 measurements
# Computing mean of 2090000 measurements
# Computing mean of 2080000 measurements
# Computing mean of 2070000 measurements
# Computing mean of 2060000 measurements
# Computing mean of 2050000 measurements
# Computing mean of 2040000 measurements
# Computing mean of 2030000 measurements
# Computing mean of 2020000 measurements
# Computing mean of 2010000 measurements
# Computing mean of 2000000 measurements
# Computing mean of 1990000 measurements
# Computing mean of 1980000 measurements
# Computing mean of 1970000 measurements
# Computing mean of 1960000 measurements
# Computing mean of 1950000 measurements
# Computing mean of 1940000 measurements
# Computing mean of 1930000 measurements
# Computing mean of 1920000 measurements
# Computing mean of 1910000 measurements
# Computing mean of 1900000 measurements
# Computing mean of 1890000 measurements
# Computing mean of 1880000 measurements
# Computing mean of 1870000 measurements
# Computing mean of 1860000 measurements
# Computing mean of 1850000 measurements
# Computing mean of 1840000 measurements
# Computing mean of 1830000 measurements
# Computing mean of 1820000 measurements
# Computing mean of 1810000 measurements
# Computing mean of 1800000 measurements
# Computing mean of 1790000 measurements
# Computing mean of 1780000 measurements
# Computing mean of 1770000 measurements
# Computing mean of 1760000 measurements
# Computing mean of 1750000 measurements
# Computing mean of 1740000 measurements
# Computing mean of 1730000 measurements
# Computing mean of 1720000 measurements
# Computing mean of 1710000 measurements
# Computing mean of 1700000 measurements
# Computing mean of 1690000 measurements
# Computing mean of 1680000 measurements
# Computing mean of 1670000 measurements
# Computing mean of 1660000 measurements
# Computing mean of 1650000 measurements
# Computing mean of 1640000 measurements
# Computing mean of 1630000 measurements
# Computing mean of 1620000 measurements
# Computing mean of 1610000 measurements
# Computing mean of 1600000 measurements
# Computing mean of 1590000 measurements
# Computing mean of 1580000 measurements
# Computing mean of 1570000 measurements
# Computing mean of 1560000 measurements
# Computing mean of 1550000 measurements
# Computing mean of 1540000 measurements
# Computing mean of 1530000 measurements
# Computing mean of 1520000 measurements
# Computing mean of 1510000 measurements
# Computing mean of 1500000 measurements
# Computing mean of 1490000 measurements
# Computing mean of 1480000 measurements
# Computing mean of 1470000 measurements
# Computing mean of 1460000 measurements
# Computing mean of 1450000 measurements
# Computing mean of 1440000 measurements
# Computing mean of 1430000 measurements
# Computing mean of 1420000 measurements
# Computing mean of 1410000 measurements
# Computing mean of 1400000 measurements
# Computing mean of 1390000 measurements
# Computing mean of 1380000 measurements
# Computing mean of 1370000 measurements
# Computing mean of 1360000 measurements
# Computing mean of 1350000 measurements
# Computing mean of 1340000 measurements
# Computing mean of 1330000 measurements
# Computing mean of 1320000 measurements
# Computing mean of 1310000 measurements
# Computing mean of 1300000 measurements
# Computing mean of 1290000 measurements
# Computing mean of 1280000 measurements
# Computing mean of 1270000 measurements
# Computing mean of 1260000 measurements
# Computing mean of 1250000 measurements
# Computing mean of 1240000 measurements
# Computing mean of 1230000 measurements
# Computing mean of 1220000 measurements
# Computing mean of 1210000 measurements
# Computing mean of 1200000 measurements
# Computing mean of 1190000 measurements
# Computing mean of 1180000 measurements
# Computing mean of 1170000 measurements
# Computing mean of 1160000 measurements
# Computing mean of 1150000 measurements
# Computing mean of 1140000 measurements
# Computing mean of 1130000 measurements
# Computing mean of 1120000 measurements
# Computing mean of 1110000 measurements
# Computing mean of 1100000 measurements
# Computing mean of 1090000 measurements
# Computing mean of 1080000 measurements
# Computing mean of 1070000 measurements
# Computing mean of 1060000 measurements
# Computing mean of 1050000 measurements
# Computing mean of 1040000 measurements
# Computing mean of 1030000 measurements
# Computing mean of 1020000 measurements
# Computing mean of 1010000 measurements
# Computing mean of 1000000 measurements
# Computing mean of 990000 measurements
# Computing mean of 980000 measurements
# Computing mean of 970000 measurements
# Computing mean of 960000 measurements
# Computing mean of 950000 measurements
# Computing mean of 940000 measurements
# Computing mean of 930000 measurements
# Computing mean of 920000 measurements
# Computing mean of 910000 measurements
# Computing mean of 900000 measurements
# Computing mean of 890000 measurements
# Computing mean of 880000 measurements
# Computing mean of 870000 measurements
# Computing mean of 860000 measurements
# Computing mean of 850000 measurements
# Computing mean of 840000 measurements
# Computing mean of 830000 measurements
# Computing mean of 820000 measurements
# Computing mean of 810000 measurements
# Computing mean of 800000 measurements
# Computing mean of 790000 measurements
# Computing mean of 780000 measurements
# Computing mean of 770000 measurements
# Computing mean of 760000 measurements
# Computing mean of 750000 measurements
# Computing mean of 740000 measurements
# Computing mean of 730000 measurements
# Computing mean of 720000 measurements
# Computing mean of 710000 measurements
# Computing mean of 700000 measurements
# Computing mean of 690000 measurements
# Computing mean of 680000 measurements
# Computing mean of 670000 measurements
# Computing mean of 660000 measurements
# Computing mean of 650000 measurements
# Computing mean of 640000 measurements
# Computing mean of 630000 measurements
# Computing mean of 620000 measurements
# Computing mean of 610000 measurements
# Computing mean of 600000 measurements
# Computing mean of 590000 measurements
# Computing mean of 580000 measurements
# Computing mean of 570000 measurements
# Computing mean of 560000 measurements
# Computing mean of 550000 measurements
# Computing mean of 540000 measurements
# Computing mean of 530000 measurements
# Computing mean of 520000 measurements
# Computing mean of 510000 measurements
# Computing mean of 500000 measurements
# Computing mean of 490000 measurements
# Computing mean of 480000 measurements
# Computing mean of 470000 measurements
# Computing mean of 460000 measurements
# Computing mean of 450000 measurements
# Computing mean of 440000 measurements
# Computing mean of 430000 measurements
# Computing mean of 420000 measurements
# Computing mean of 410000 measurements
# Computing mean of 400000 measurements
# Computing mean of 390000 measurements
# Computing mean of 380000 measurements
# Computing mean of 370000 measurements
# Computing mean of 360000 measurements
# Computing mean of 350000 measurements
# Computing mean of 340000 measurements
# Computing mean of 330000 measurements
# Computing mean of 320000 measurements
# Computing mean of 310000 measurements
# Computing mean of 300000 measurements
# Computing mean of 290000 measurements
# Computing mean of 280000 measurements
# Computing mean of 270000 measurements
# Computing mean of 260000 measurements
# Computing mean of 250000 measurements
# Computing mean of 240000 measurements
# Computing mean of 230000 measurements
# Computing mean of 220000 measurements
# Computing mean of 210000 measurements
# Computing mean of 200000 measurements
# Computing mean of 190000 measurements
# Computing mean of 180000 measurements
# Computing mean of 170000 measurements
# Computing mean of 160000 measurements
# Computing mean of 150000 measurements
# Computing mean of 140000 measurements
# Computing mean of 130000 measurements
# Computing mean of 120000 measurements
# Computing mean of 110000 measurements
# Computing mean of 100000 measurements
# Computing mean of 90000 measurements
# Computing mean of 80000 measurements
# Computing mean of 70000 measurements
# Computing mean of 60000 measurements
# Computing mean of 50000 measurements
# Computing mean of 40000 measurements
# Computing mean of 30000 measurements
# Computing mean of 20000 measurements
# Computing mean of 10000 measurements

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.subplots_adjust(wspace=0.2)
ax1.errorbar(delays, MSDs, yerr=SEMs)
ax1.set_ylabel(r'$\langle \theta(\tau)^2 \rangle$ (degrees$^2$)')
ax1.set_xlabel(r'Time delay $\tau$ (frames)')

ax2.errorbar(delays, MSDs, yerr=SEMs)
ax2.set_ylabel(r'$\langle \theta(\tau)^2 \rangle$ (degrees$^2$)')
ax2.set_xlabel(r'Time delay $\tau$ (frames)')
ax2.set_xscale('log')
ax2.set_yscale('log')

# %%
ten_percent = 0.1*len(delays)
ninety_percent = 0.9*len(delays)
slope, intercept, r_value, p_value, std_err = stats.linregress(delays[ten_percent:ninety_percent]*10**-14,
                                                               MSDs[ten_percent:ninety_percent])
# Out:
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   app.launch_new_instance()
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
print(slope)
print(slope/2)
# Out:
# -5.61100568547e+14
# -2.80550284274e+14

# %%
# Femtosecond is 10**-15
# Each frame is 10 fs = 10**-14
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.subplots_adjust(wspace=0.2)
ax1.errorbar(delays*10**-14, MSDs, yerr=SEMs)
ax1.plot(delays[ten_percent:ninety_percent]*10**-14, MSDs[ten_percent:ninety_percent], c='r', label='Data used for fit')
ax1.set_ylabel(r'$\langle \theta(\tau)^2 \rangle$ (degrees$^2$)')
ax1.set_xlabel(r'Time delay $\tau$ (seconds)')
ax1.legend()

ax2.errorbar(delays*10**-14, MSDs, yerr=SEMs)
ax2.plot(delays[ten_percent:ninety_percent]*10**-14, slope*delays[ten_percent:ninety_percent]*10**-14+intercept, c='g', ls='-', label='Linear fit')
ax2.plot(delays[0:ten_percent]*10**-14, slope*delays[0:ten_percent]*10**-14+intercept, c='g', ls='--')
ax2.plot(delays[ninety_percent:]*10**-14, slope*delays[ninety_percent:]*10**-14+intercept, c='g', ls='--')
ax2.set_ylabel(r'$\langle \theta(\tau)^2 \rangle$ (degrees$^2$)')
ax2.set_xlabel(r'Time delay $\tau$ (seconds)')
ax2.ticklabel_format(style='sci', axis='both', scilimits=(0,0))
ax2.xaxis.major.formatter._useMathText = True
ax2.legend()
# Out:
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:12: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:13: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/dslochower/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:14: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# # Read in the 100 shorter simulations

# %%
runs = range(1, 100)
prefix = '/home/dslochower/data/projects/nonequilibrium/'
squared_displacement = np.empty((len(runs)))
end_points = np.empty((len(runs)))
end_positions = 250000

slopes = np.empty((len(runs)))
sems = np.empty((len(runs)))


for run in runs:
    try: 
        print(run)
        os.chdir(prefix + 'md-data//butane-rotational-diffusion/entropy-md-data/'+str(run))
        datum = np.genfromtxt('cccc.dat')
        distances = np.diff(datum[:, 1])
        flips = np.where(distances > 100)[0] # Where the torsion goes from negative to positive, so we subtract 360 for displacement
        flops = np.where(distances < -100)[0] # Where the torsion goes from negative to positive, so we add 360 for displacement
        unwrapped_datum = np.copy(datum)N = add/subtract heat every this many timesteps
eflux = rate of heat addition or subtraction (energy/time units)
eflux can be a variable (see below)

        for subtraction in flips: 
            unwrapped_datum[subtraction + 1:, 1] -= 360
        for addition in flops: 
            unwrapped_datum[addition + 1:, 1] += 360
        unwrapped_positions = unwrapped_datum[:, 1]
        
        delays = np.arange(10000, len(unwrapped_positions) - 1, 10000)
        MSDs = np.empty((len(delays)))
        SEMs = np.empty((len(delays)))
        for delay in delays:
            MSDs[np.where(delays==delay)[0]], SEMs[np.where(delays==delay)[0]] = compute_msd(unwrapped_positions, delay)
            
        times = delays * 10**-14
        slope, intercept, r_value, p_value, std_err = sc.stats.linregress(times, MSDs)
        slopes[run -1] = slope
        sems[run - 1] = std_err
        os.chdir(prefix + 'md-data//butane-rotational-diffusion/entropy-md-data/')
    except Exception as e:
        print(e)
    except:
        squared_displacement[run - 1] = np.nan
        end_points[run - 1] = np.nan
# Out:
#   File "<ipython-input-3-a53694528820>", line 19
#     unwrapped_datum = np.copy(datum)N = add/subtract heat every this many timesteps
#                                     ^
# SyntaxError: invalid syntax

# %%
print('{0:2.2e} +/- {1:2.2e}'.format(np.mean(slopes / 2), np.sqrt(np.sum((sems/2)**2))))
# Out:
# 1.81e+15 +/- 1.78e+15

# %% [markdown]
# # Same loop as above, but plotting now.

# %%
def compute_msd(trajectory, delta):
    ''' For a given time interval, compute the displacements of the angle. For small time deltas,
    there are many displacements in the trajectory. As the delta gets bigger, there are fewer
    and fewer displacements.'''
    number_measurements = len(trajectory) - delta
    print('Computing mean of {} measurements'.format(number_measurements))
    displacements = np.empty((number_measurements))
    for time in range(number_measurements):
        displacements[time] = trajectory[time + delta] - trajectory[time]
    return np.mean(displacements**2), stats.sem(displacements**2)

# %%
runs = range(1, 100)
prefix = '/home/dslochower/data/projects/nonequilibrium/'
squared_displacement = np.empty((len(runs)))


delays = np.arange(10000, 500000 - 1, 100000)
all_MSDs = np.empty((len(runs), len(delays)))

for run in runs:
    try: 
        print(run)
        os.chdir(prefix + 'md-data//butane-rotational-diffusion/md-data/Langevin-dynamics-10fs-recording/'+str(run))
        datum = np.genfromtxt('cccc.dat')
        distances = np.diff(datum[:, 1])
        flips = np.where(distances > 100)[0] # Where the torsion goes from negative to positive, so we subtract 360 for displacement
        flops = np.where(distances < -100)[0] # Where the torsion goes from negative to positive, so we add 360 for displacement
        unwrapped_datum = np.copy(datum)

        for subtraction in flips: 
            unwrapped_datum[subtraction + 1:, 1] -= 360
        for addition in flops: 
            unwrapped_datum[addition + 1:, 1] += 360
        unwrapped_positions = unwrapped_datum[:, 1]
        
        MSDs = np.empty((len(delays)))
        SEMs = np.empty((len(delays)))
        for delay in delays:
            MSDs[np.where(delays==delay)[0]], SEMs[np.where(delays==delay)[0]] = compute_msd(unwrapped_positions, delay)
            
        times = delays * 10**-14
        all_MSDs[run - 1] = MSDs
        
        os.chdir(prefix + 'md-data//butane-rotational-diffusion/md-data/Langevin-dynamics-10fs-recording/'+str(run))
    except Exception as e:
        print(e)
    except:
        squared_displacement[run - 1] = np.nan
        end_points[run - 1] = np.nan
# Out:
# 1
# Computing mean of 490000 measurements
# Computing mean of 390000 measurements
# Computing mean of 290000 measurements
# Computing mean of 190000 measurements
# Computing mean of 90000 measurements
# 2
# Computing mean of 490000 measurements
# Computing mean of 390000 measurements
# Computing mean of 290000 measurements
# Computing mean of 190000 measurements
# Computing mean of 90000 measurements
# 3

# %%
delays
# Out:
# array([ 10000, 110000, 210000, 310000, 410000])
